# %%
from pycaret.classification import *
import pandas as pd
from sklearn.metrics import confusion_matrix, roc_curve, auc
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import LabelBinarizer
import os
import shutil
import numpy as np
import warnings

plt.rcParams['font.family'] = 'Arial'
warnings.filterwarnings('ignore')

# %% [markdown]
# # Train model

# %% [markdown]
# auto extracted data

# %%
# hearing loss classificaiton
# Load data
data_path = 'data/train_extract.csv'
# prepare data
data = pd.read_csv(data_path, index_col=0).drop(['severity'], axis=1)
label = ['CHL','SNHL', 'Mixed HL', 'Normal hearing']
data['hearing_loss'] = data['hearing_loss'].map(lambda x: label.index(x))

# setup
experiment_name = 'extract_hearing_loss'
clf = setup(data=data, target='hearing_loss', use_gpu=True, session_id=123, experiment_name=experiment_name)
best_auto = compare_models(n_select=5)

# save model
os.makedirs('models', exist_ok=True)
save_path = os.path.join('models', experiment_name + '_model')
save_model(best_auto[0], save_path)

# evaluate model
eval_dir = os.path.join('evaluate', experiment_name)
os.makedirs(eval_dir, exist_ok=True)    
cf = plot_model(best_auto[0], plot='confusion_matrix', save=True)
roc = plot_model(best_auto[0], save=True)
feature_importance = plot_model(best_auto[0], plot='feature', save=True)

# move evaluate files to evaluate folder
shutil.move('Confusion Matrix.png', os.path.join(eval_dir, 'confusion_matrix.png'))
shutil.move('AUC.png', os.path.join(eval_dir, 'roc.png'))
shutil.move('Feature Importance.png', os.path.join(eval_dir, 'feature_importance.png'))

# test on test set
data_test_path = 'data/test_extract.csv'
data_test = pd.read_csv(data_test_path, index_col=0).drop(['severity'], axis=1)
data_test['hearing_loss'] = data_test['hearing_loss'].map(lambda x: label.index(x))

model = load_model(save_path)
predict_model(model, data=data_test)
# Out:
# <style type="text/css">
# #T_02ca7_row8_col1, #T_02ca7_row15_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_02ca7">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_02ca7_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_02ca7_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_02ca7_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_02ca7_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_02ca7_row0_col1" class="data row0 col1" >123</td>
#     </tr>
#     <tr>
#       <th id="T_02ca7_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_02ca7_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_02ca7_row1_col1" class="data row1 col1" >hearing_loss</td>
#     </tr>
#     <tr>
#       <th id="T_02ca7_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_02ca7_row2_col0" class="data row2 col0" >Target type</td>
#       <td id="T_02ca7_row2_col1" class="data row2 col1" >Multiclass</td>
#     </tr>
#     <tr>
#       <th id="T_02ca7_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_02ca7_row3_col0" class="data row3 col0" >Original data shape</td>
#       <td id="T_02ca7_row3_col1" class="data row3 col1" >(2810, 17)</td>
#     </tr>
#     <tr>
#       <th id="T_02ca7_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_02ca7_row4_col0" class="data row4 col0" >Transformed data shape</td>
#       <td id="T_02ca7_row4_col1" class="data row4 col1" >(2810, 17)</td>
#     </tr>
#     <tr>
#       <th id="T_02ca7_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_02ca7_row5_col0" class="data row5 col0" >Transformed train set shape</td>
#       <td id="T_02ca7_row5_col1" class="data row5 col1" >(1966, 17)</td>
#     </tr>
#     <tr>
#       <th id="T_02ca7_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_02ca7_row6_col0" class="data row6 col0" >Transformed test set shape</td>
#       <td id="T_02ca7_row6_col1" class="data row6 col1" >(844, 17)</td>
#     </tr>
#     <tr>
#       <th id="T_02ca7_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_02ca7_row7_col0" class="data row7 col0" >Numeric features</td>
#       <td id="T_02ca7_row7_col1" class="data row7 col1" >16</td>
#     </tr>
#     <tr>
#       <th id="T_02ca7_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_02ca7_row8_col0" class="data row8 col0" >Preprocess</td>
#       <td id="T_02ca7_row8_col1" class="data row8 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_02ca7_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_02ca7_row9_col0" class="data row9 col0" >Imputation type</td>
#       <td id="T_02ca7_row9_col1" class="data row9 col1" >simple</td>
#     </tr>
#     <tr>
#       <th id="T_02ca7_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_02ca7_row10_col0" class="data row10 col0" >Numeric imputation</td>
#       <td id="T_02ca7_row10_col1" class="data row10 col1" >mean</td>
#     </tr>
#     <tr>
#       <th id="T_02ca7_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_02ca7_row11_col0" class="data row11 col0" >Categorical imputation</td>
#       <td id="T_02ca7_row11_col1" class="data row11 col1" >mode</td>
#     </tr>
#     <tr>
#       <th id="T_02ca7_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_02ca7_row12_col0" class="data row12 col0" >Fold Generator</td>
#       <td id="T_02ca7_row12_col1" class="data row12 col1" >StratifiedKFold</td>
#     </tr>
#     <tr>
#       <th id="T_02ca7_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_02ca7_row13_col0" class="data row13 col0" >Fold Number</td>
#       <td id="T_02ca7_row13_col1" class="data row13 col1" >10</td>
#     </tr>
#     <tr>
#       <th id="T_02ca7_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_02ca7_row14_col0" class="data row14 col0" >CPU Jobs</td>
#       <td id="T_02ca7_row14_col1" class="data row14 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_02ca7_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_02ca7_row15_col0" class="data row15 col0" >Use GPU</td>
#       <td id="T_02ca7_row15_col1" class="data row15 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_02ca7_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_02ca7_row16_col0" class="data row16 col0" >Log Experiment</td>
#       <td id="T_02ca7_row16_col1" class="data row16 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_02ca7_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_02ca7_row17_col0" class="data row17 col0" >Experiment Name</td>
#       <td id="T_02ca7_row17_col1" class="data row17 col1" >extract_hearing_loss</td>
#     </tr>
#     <tr>
#       <th id="T_02ca7_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_02ca7_row18_col0" class="data row18 col0" >USI</td>
#       <td id="T_02ca7_row18_col1" class="data row18 col1" >db96</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_75958 th {
#   text-align: left;
# }
# #T_75958_row0_col0, #T_75958_row0_col2, #T_75958_row0_col6, #T_75958_row0_col7, #T_75958_row1_col0, #T_75958_row1_col1, #T_75958_row1_col3, #T_75958_row1_col4, #T_75958_row1_col5, #T_75958_row2_col0, #T_75958_row2_col1, #T_75958_row2_col2, #T_75958_row2_col3, #T_75958_row2_col4, #T_75958_row2_col5, #T_75958_row2_col6, #T_75958_row2_col7, #T_75958_row3_col0, #T_75958_row3_col1, #T_75958_row3_col2, #T_75958_row3_col3, #T_75958_row3_col4, #T_75958_row3_col5, #T_75958_row3_col6, #T_75958_row3_col7, #T_75958_row4_col0, #T_75958_row4_col1, #T_75958_row4_col2, #T_75958_row4_col3, #T_75958_row4_col4, #T_75958_row4_col5, #T_75958_row4_col6, #T_75958_row4_col7, #T_75958_row5_col0, #T_75958_row5_col1, #T_75958_row5_col2, #T_75958_row5_col3, #T_75958_row5_col4, #T_75958_row5_col5, #T_75958_row5_col6, #T_75958_row5_col7, #T_75958_row6_col0, #T_75958_row6_col1, #T_75958_row6_col2, #T_75958_row6_col3, #T_75958_row6_col4, #T_75958_row6_col5, #T_75958_row6_col6, #T_75958_row6_col7, #T_75958_row7_col0, #T_75958_row7_col1, #T_75958_row7_col2, #T_75958_row7_col3, #T_75958_row7_col4, #T_75958_row7_col5, #T_75958_row7_col6, #T_75958_row7_col7, #T_75958_row8_col0, #T_75958_row8_col1, #T_75958_row8_col2, #T_75958_row8_col3, #T_75958_row8_col4, #T_75958_row8_col5, #T_75958_row8_col6, #T_75958_row8_col7, #T_75958_row9_col0, #T_75958_row9_col1, #T_75958_row9_col2, #T_75958_row9_col3, #T_75958_row9_col4, #T_75958_row9_col5, #T_75958_row9_col6, #T_75958_row9_col7, #T_75958_row10_col0, #T_75958_row10_col1, #T_75958_row10_col2, #T_75958_row10_col3, #T_75958_row10_col4, #T_75958_row10_col5, #T_75958_row10_col6, #T_75958_row10_col7, #T_75958_row11_col0, #T_75958_row11_col1, #T_75958_row11_col2, #T_75958_row11_col3, #T_75958_row11_col4, #T_75958_row11_col5, #T_75958_row11_col6, #T_75958_row11_col7, #T_75958_row12_col0, #T_75958_row12_col1, #T_75958_row12_col2, #T_75958_row12_col3, #T_75958_row12_col4, #T_75958_row12_col5, #T_75958_row12_col6, #T_75958_row12_col7, #T_75958_row13_col0, #T_75958_row13_col1, #T_75958_row13_col2, #T_75958_row13_col3, #T_75958_row13_col4, #T_75958_row13_col5, #T_75958_row13_col6, #T_75958_row13_col7 {
#   text-align: left;
# }
# #T_75958_row0_col1, #T_75958_row0_col3, #T_75958_row0_col4, #T_75958_row0_col5, #T_75958_row1_col2, #T_75958_row1_col6, #T_75958_row1_col7 {
#   text-align: left;
#   background-color: yellow;
# }
# #T_75958_row0_col8, #T_75958_row1_col8, #T_75958_row2_col8, #T_75958_row3_col8, #T_75958_row4_col8, #T_75958_row5_col8, #T_75958_row6_col8, #T_75958_row7_col8, #T_75958_row8_col8, #T_75958_row9_col8, #T_75958_row10_col8, #T_75958_row12_col8, #T_75958_row13_col8 {
#   text-align: left;
#   background-color: lightgrey;
# }
# #T_75958_row11_col8 {
#   text-align: left;
#   background-color: yellow;
#   background-color: lightgrey;
# }
# </style>
# <table id="T_75958">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_75958_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_75958_level0_col1" class="col_heading level0 col1" >Accuracy</th>
#       <th id="T_75958_level0_col2" class="col_heading level0 col2" >AUC</th>
#       <th id="T_75958_level0_col3" class="col_heading level0 col3" >Recall</th>
#       <th id="T_75958_level0_col4" class="col_heading level0 col4" >Prec.</th>
#       <th id="T_75958_level0_col5" class="col_heading level0 col5" >F1</th>
#       <th id="T_75958_level0_col6" class="col_heading level0 col6" >Kappa</th>
#       <th id="T_75958_level0_col7" class="col_heading level0 col7" >MCC</th>
#       <th id="T_75958_level0_col8" class="col_heading level0 col8" >TT (Sec)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_75958_level0_row0" class="row_heading level0 row0" >gbc</th>
#       <td id="T_75958_row0_col0" class="data row0 col0" >Gradient Boosting Classifier</td>
#       <td id="T_75958_row0_col1" class="data row0 col1" >0.8448</td>
#       <td id="T_75958_row0_col2" class="data row0 col2" >0.9462</td>
#       <td id="T_75958_row0_col3" class="data row0 col3" >0.8448</td>
#       <td id="T_75958_row0_col4" class="data row0 col4" >0.8432</td>
#       <td id="T_75958_row0_col5" class="data row0 col5" >0.8413</td>
#       <td id="T_75958_row0_col6" class="data row0 col6" >0.7177</td>
#       <td id="T_75958_row0_col7" class="data row0 col7" >0.7198</td>
#       <td id="T_75958_row0_col8" class="data row0 col8" >3.1230</td>
#     </tr>
#     <tr>
#       <th id="T_75958_level0_row1" class="row_heading level0 row1" >lightgbm</th>
#       <td id="T_75958_row1_col0" class="data row1 col0" >Light Gradient Boosting Machine</td>
#       <td id="T_75958_row1_col1" class="data row1 col1" >0.8433</td>
#       <td id="T_75958_row1_col2" class="data row1 col2" >0.9466</td>
#       <td id="T_75958_row1_col3" class="data row1 col3" >0.8433</td>
#       <td id="T_75958_row1_col4" class="data row1 col4" >0.8418</td>
#       <td id="T_75958_row1_col5" class="data row1 col5" >0.8409</td>
#       <td id="T_75958_row1_col6" class="data row1 col6" >0.7186</td>
#       <td id="T_75958_row1_col7" class="data row1 col7" >0.7200</td>
#       <td id="T_75958_row1_col8" class="data row1 col8" >2.5320</td>
#     </tr>
#     <tr>
#       <th id="T_75958_level0_row2" class="row_heading level0 row2" >rf</th>
#       <td id="T_75958_row2_col0" class="data row2 col0" >Random Forest Classifier</td>
#       <td id="T_75958_row2_col1" class="data row2 col1" >0.8357</td>
#       <td id="T_75958_row2_col2" class="data row2 col2" >0.9427</td>
#       <td id="T_75958_row2_col3" class="data row2 col3" >0.8357</td>
#       <td id="T_75958_row2_col4" class="data row2 col4" >0.8361</td>
#       <td id="T_75958_row2_col5" class="data row2 col5" >0.8301</td>
#       <td id="T_75958_row2_col6" class="data row2 col6" >0.6946</td>
#       <td id="T_75958_row2_col7" class="data row2 col7" >0.6997</td>
#       <td id="T_75958_row2_col8" class="data row2 col8" >0.2510</td>
#     </tr>
#     <tr>
#       <th id="T_75958_level0_row3" class="row_heading level0 row3" >et</th>
#       <td id="T_75958_row3_col0" class="data row3 col0" >Extra Trees Classifier</td>
#       <td id="T_75958_row3_col1" class="data row3 col1" >0.8326</td>
#       <td id="T_75958_row3_col2" class="data row3 col2" >0.9416</td>
#       <td id="T_75958_row3_col3" class="data row3 col3" >0.8326</td>
#       <td id="T_75958_row3_col4" class="data row3 col4" >0.8335</td>
#       <td id="T_75958_row3_col5" class="data row3 col5" >0.8234</td>
#       <td id="T_75958_row3_col6" class="data row3 col6" >0.6837</td>
#       <td id="T_75958_row3_col7" class="data row3 col7" >0.6926</td>
#       <td id="T_75958_row3_col8" class="data row3 col8" >0.2000</td>
#     </tr>
#     <tr>
#       <th id="T_75958_level0_row4" class="row_heading level0 row4" >dt</th>
#       <td id="T_75958_row4_col0" class="data row4 col0" >Decision Tree Classifier</td>
#       <td id="T_75958_row4_col1" class="data row4 col1" >0.7919</td>
#       <td id="T_75958_row4_col2" class="data row4 col2" >0.8118</td>
#       <td id="T_75958_row4_col3" class="data row4 col3" >0.7919</td>
#       <td id="T_75958_row4_col4" class="data row4 col4" >0.7932</td>
#       <td id="T_75958_row4_col5" class="data row4 col5" >0.7906</td>
#       <td id="T_75958_row4_col6" class="data row4 col6" >0.6272</td>
#       <td id="T_75958_row4_col7" class="data row4 col7" >0.6286</td>
#       <td id="T_75958_row4_col8" class="data row4 col8" >0.0320</td>
#     </tr>
#     <tr>
#       <th id="T_75958_level0_row5" class="row_heading level0 row5" >lr</th>
#       <td id="T_75958_row5_col0" class="data row5 col0" >Logistic Regression</td>
#       <td id="T_75958_row5_col1" class="data row5 col1" >0.7838</td>
#       <td id="T_75958_row5_col2" class="data row5 col2" >0.9022</td>
#       <td id="T_75958_row5_col3" class="data row5 col3" >0.7838</td>
#       <td id="T_75958_row5_col4" class="data row5 col4" >0.7767</td>
#       <td id="T_75958_row5_col5" class="data row5 col5" >0.7761</td>
#       <td id="T_75958_row5_col6" class="data row5 col6" >0.6027</td>
#       <td id="T_75958_row5_col7" class="data row5 col7" >0.6060</td>
# Transformation Pipeline and Model Successfully Saved
# Transformation Pipeline and Model Successfully Loaded
# <style type="text/css">
# </style>
# <table id="T_7f649">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_7f649_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_7f649_level0_col1" class="col_heading level0 col1" >Accuracy</th>
#       <th id="T_7f649_level0_col2" class="col_heading level0 col2" >AUC</th>
#       <th id="T_7f649_level0_col3" class="col_heading level0 col3" >Recall</th>
#       <th id="T_7f649_level0_col4" class="col_heading level0 col4" >Prec.</th>
#       <th id="T_7f649_level0_col5" class="col_heading level0 col5" >F1</th>
#       <th id="T_7f649_level0_col6" class="col_heading level0 col6" >Kappa</th>
#       <th id="T_7f649_level0_col7" class="col_heading level0 col7" >MCC</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_7f649_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_7f649_row0_col0" class="data row0 col0" >Gradient Boosting Classifier</td>
#       <td id="T_7f649_row0_col1" class="data row0 col1" >0.8431</td>
#       <td id="T_7f649_row0_col2" class="data row0 col2" >0.9501</td>
#       <td id="T_7f649_row0_col3" class="data row0 col3" >0.8431</td>
#       <td id="T_7f649_row0_col4" class="data row0 col4" >0.8430</td>
#       <td id="T_7f649_row0_col5" class="data row0 col5" >0.8420</td>
#       <td id="T_7f649_row0_col6" class="data row0 col6" >0.7111</td>
#       <td id="T_7f649_row0_col7" class="data row0 col7" >0.7118</td>
#     </tr>
#   </tbody>
# </table>
#         pta_ac     pta_bc    sl   srt     pb     250_ac     500_ac    1000_ac  \
# 0    63.591644  64.071594  95.0  60.0   68.0  40.196838  54.898613  65.444397
# 1    65.624359  50.412266  20.0  45.0    1.0  61.966286  51.229630  46.049465
# 2    18.780752  17.239866  20.0  20.0    7.0  83.625534  60.467449  61.188725
# 3    20.938475  20.690275  30.0  20.0    0.0  16.068274  21.318129  35.746330
# 4    28.033876  25.640808  30.0  30.0    2.0  17.661442  22.450958  25.015066
# ..         ...        ...   ...   ...    ...        ...        ...        ...
# 696  41.159649  27.472963   3.0  40.0   96.0  21.179117  16.434290  10.912289
# 697  15.030734  15.166432  25.0  15.0  100.0  46.046581  41.542656  36.338326
# 698  14.949298  13.343937  30.0  60.0   16.0  21.777626  21.495274  17.106976
# 699  24.182043  23.148726  30.0  29.0   96.0  45.949978  25.913429  30.344566
# 700  23.820906  23.944550  30.0  25.0   96.0  45.153625  41.464161  51.317585
#
#        2000_ac    4000_ac    6000_ac    8000_ac     500_bc    1000_bc  \
# 0    64.824577  75.627983  86.033691  95.068665  54.550320  60.974411
# 1    30.854788  55.671494  66.460533  57.419689  51.462425  46.110741
# 2    62.374153  46.100647  51.843330  71.768677  17.725185  22.247004
# 3    51.314316  70.878555  79.959961  75.858986  22.282335  35.368431
# 4    25.196245  45.040977  31.812569  22.838676  21.910337  21.336765
# ..         ...        ...        ...        ...        ...        ...
# 696  20.798878  25.594488  25.648846  40.940872  15.324203   9.126860
# 697  40.677994  59.986267  49.410858  45.970680  21.830103  11.442636
# 698  21.407763  40.408695  61.193295  55.400532  20.939615  12.351708
# 699  16.912123  35.910408  26.038538  45.192055  24.936766  26.368303
# 700  46.689053  61.013226  65.135162  74.974983  22.465633  30.589321
#
#        2000_bc    4000_bc  hearing_loss  prediction_label  prediction_score
# 0    65.577675  71.095963             1                 1            0.9725
# 1    70.737244  54.896503             1                 1            0.8914
# 2    31.614569  22.422012             3                 3            0.4825
# 3    45.790504  71.243340             1                 1            0.8666
# 4    25.935600  45.537395             1                 1            0.9528
# ..         ...        ...           ...               ...               ...
# 696  21.081354  26.238901             2                 2            0.8659
# 697  17.679497  26.203426             3                 3            0.7456
# 698  20.610508  40.582226             1                 1            0.5843
# 699  17.177185  35.311920             1                 1            0.7768
# 700  35.445293  41.176735             1                 1            0.8657
#
# [701 rows x 19 columns]

# %%
# severity classificaiton
# Load data
data_path = 'data/train_extract.csv'
# prepare data
data = pd.read_csv(data_path, index_col=0).drop(['hearing_loss'], axis=1)
label = ['Normal','Mild', 'Moderate', 'Moderately severe',  'Severe', 'Profound']
data['severity'] = data['severity'].map(lambda x: label.index(x))

# setup
experiment_name = 'extract_severity'
clf = setup(data=data, target='severity', use_gpu=True, session_id=123, experiment_name=experiment_name)
best_auto = compare_models(n_select=5)

# save model
os.makedirs('models', exist_ok=True)
save_path = os.path.join('models',experiment_name + '_model')
save_model(best_auto[0], save_path)

# evaluate model
eval_dir = os.path.join('evaluate', experiment_name)
os.makedirs(eval_dir,exist_ok=True)    
cf = plot_model(best_auto[0], plot='confusion_matrix', save=True)
roc = plot_model(best_auto[0], save=True)
feature_importance = plot_model(best_auto[0], plot='feature', save=True)

# move evaluate files to evaluate folder
shutil.move('Confusion Matrix.png', os.path.join(eval_dir, 'confusion_matrix.png'))
shutil.move('AUC.png', os.path.join(eval_dir, 'roc.png'))
shutil.move('Feature Importance.png', os.path.join(eval_dir, 'feature_importance.png'))

# test on test set
data_test_path = 'data/test_extract.csv'
data_test = pd.read_csv(data_test_path, index_col=0).drop(['hearing_loss'], axis=1)
data_test['severity'] = data_test['severity'].map(lambda x: label.index(x))

model = load_model(save_path)
predict_model(model, data=data_test)
# Out:
# <style type="text/css">
# #T_6ee4e_row8_col1, #T_6ee4e_row15_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_6ee4e">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_6ee4e_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_6ee4e_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_6ee4e_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_6ee4e_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_6ee4e_row0_col1" class="data row0 col1" >123</td>
#     </tr>
#     <tr>
#       <th id="T_6ee4e_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_6ee4e_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_6ee4e_row1_col1" class="data row1 col1" >severity</td>
#     </tr>
#     <tr>
#       <th id="T_6ee4e_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_6ee4e_row2_col0" class="data row2 col0" >Target type</td>
#       <td id="T_6ee4e_row2_col1" class="data row2 col1" >Multiclass</td>
#     </tr>
#     <tr>
#       <th id="T_6ee4e_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_6ee4e_row3_col0" class="data row3 col0" >Original data shape</td>
#       <td id="T_6ee4e_row3_col1" class="data row3 col1" >(2810, 17)</td>
#     </tr>
#     <tr>
#       <th id="T_6ee4e_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_6ee4e_row4_col0" class="data row4 col0" >Transformed data shape</td>
#       <td id="T_6ee4e_row4_col1" class="data row4 col1" >(2810, 17)</td>
#     </tr>
#     <tr>
#       <th id="T_6ee4e_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_6ee4e_row5_col0" class="data row5 col0" >Transformed train set shape</td>
#       <td id="T_6ee4e_row5_col1" class="data row5 col1" >(1966, 17)</td>
#     </tr>
#     <tr>
#       <th id="T_6ee4e_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_6ee4e_row6_col0" class="data row6 col0" >Transformed test set shape</td>
#       <td id="T_6ee4e_row6_col1" class="data row6 col1" >(844, 17)</td>
#     </tr>
#     <tr>
#       <th id="T_6ee4e_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_6ee4e_row7_col0" class="data row7 col0" >Numeric features</td>
#       <td id="T_6ee4e_row7_col1" class="data row7 col1" >16</td>
#     </tr>
#     <tr>
#       <th id="T_6ee4e_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_6ee4e_row8_col0" class="data row8 col0" >Preprocess</td>
#       <td id="T_6ee4e_row8_col1" class="data row8 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_6ee4e_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_6ee4e_row9_col0" class="data row9 col0" >Imputation type</td>
#       <td id="T_6ee4e_row9_col1" class="data row9 col1" >simple</td>
#     </tr>
#     <tr>
#       <th id="T_6ee4e_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_6ee4e_row10_col0" class="data row10 col0" >Numeric imputation</td>
#       <td id="T_6ee4e_row10_col1" class="data row10 col1" >mean</td>
#     </tr>
#     <tr>
#       <th id="T_6ee4e_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_6ee4e_row11_col0" class="data row11 col0" >Categorical imputation</td>
#       <td id="T_6ee4e_row11_col1" class="data row11 col1" >mode</td>
#     </tr>
#     <tr>
#       <th id="T_6ee4e_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_6ee4e_row12_col0" class="data row12 col0" >Fold Generator</td>
#       <td id="T_6ee4e_row12_col1" class="data row12 col1" >StratifiedKFold</td>
#     </tr>
#     <tr>
#       <th id="T_6ee4e_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_6ee4e_row13_col0" class="data row13 col0" >Fold Number</td>
#       <td id="T_6ee4e_row13_col1" class="data row13 col1" >10</td>
#     </tr>
#     <tr>
#       <th id="T_6ee4e_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_6ee4e_row14_col0" class="data row14 col0" >CPU Jobs</td>
#       <td id="T_6ee4e_row14_col1" class="data row14 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_6ee4e_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_6ee4e_row15_col0" class="data row15 col0" >Use GPU</td>
#       <td id="T_6ee4e_row15_col1" class="data row15 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_6ee4e_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_6ee4e_row16_col0" class="data row16 col0" >Log Experiment</td>
#       <td id="T_6ee4e_row16_col1" class="data row16 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_6ee4e_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_6ee4e_row17_col0" class="data row17 col0" >Experiment Name</td>
#       <td id="T_6ee4e_row17_col1" class="data row17 col1" >extract_severity</td>
#     </tr>
#     <tr>
#       <th id="T_6ee4e_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_6ee4e_row18_col0" class="data row18 col0" >USI</td>
#       <td id="T_6ee4e_row18_col1" class="data row18 col1" >905b</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_0b4f6 th {
#   text-align: left;
# }
# #T_0b4f6_row0_col0, #T_0b4f6_row1_col0, #T_0b4f6_row1_col1, #T_0b4f6_row1_col2, #T_0b4f6_row1_col3, #T_0b4f6_row1_col4, #T_0b4f6_row1_col5, #T_0b4f6_row1_col6, #T_0b4f6_row1_col7, #T_0b4f6_row2_col0, #T_0b4f6_row2_col1, #T_0b4f6_row2_col2, #T_0b4f6_row2_col3, #T_0b4f6_row2_col4, #T_0b4f6_row2_col5, #T_0b4f6_row2_col6, #T_0b4f6_row2_col7, #T_0b4f6_row3_col0, #T_0b4f6_row3_col1, #T_0b4f6_row3_col2, #T_0b4f6_row3_col3, #T_0b4f6_row3_col4, #T_0b4f6_row3_col5, #T_0b4f6_row3_col6, #T_0b4f6_row3_col7, #T_0b4f6_row4_col0, #T_0b4f6_row4_col1, #T_0b4f6_row4_col2, #T_0b4f6_row4_col3, #T_0b4f6_row4_col4, #T_0b4f6_row4_col5, #T_0b4f6_row4_col6, #T_0b4f6_row4_col7, #T_0b4f6_row5_col0, #T_0b4f6_row5_col1, #T_0b4f6_row5_col2, #T_0b4f6_row5_col3, #T_0b4f6_row5_col4, #T_0b4f6_row5_col5, #T_0b4f6_row5_col6, #T_0b4f6_row5_col7, #T_0b4f6_row6_col0, #T_0b4f6_row6_col1, #T_0b4f6_row6_col2, #T_0b4f6_row6_col3, #T_0b4f6_row6_col4, #T_0b4f6_row6_col5, #T_0b4f6_row6_col6, #T_0b4f6_row6_col7, #T_0b4f6_row7_col0, #T_0b4f6_row7_col1, #T_0b4f6_row7_col2, #T_0b4f6_row7_col3, #T_0b4f6_row7_col4, #T_0b4f6_row7_col5, #T_0b4f6_row7_col6, #T_0b4f6_row7_col7, #T_0b4f6_row8_col0, #T_0b4f6_row8_col1, #T_0b4f6_row8_col2, #T_0b4f6_row8_col3, #T_0b4f6_row8_col4, #T_0b4f6_row8_col5, #T_0b4f6_row8_col6, #T_0b4f6_row8_col7, #T_0b4f6_row9_col0, #T_0b4f6_row9_col1, #T_0b4f6_row9_col2, #T_0b4f6_row9_col3, #T_0b4f6_row9_col4, #T_0b4f6_row9_col5, #T_0b4f6_row9_col6, #T_0b4f6_row9_col7, #T_0b4f6_row10_col0, #T_0b4f6_row10_col1, #T_0b4f6_row10_col2, #T_0b4f6_row10_col3, #T_0b4f6_row10_col4, #T_0b4f6_row10_col5, #T_0b4f6_row10_col6, #T_0b4f6_row10_col7, #T_0b4f6_row11_col0, #T_0b4f6_row11_col1, #T_0b4f6_row11_col2, #T_0b4f6_row11_col3, #T_0b4f6_row11_col4, #T_0b4f6_row11_col5, #T_0b4f6_row11_col6, #T_0b4f6_row11_col7, #T_0b4f6_row12_col0, #T_0b4f6_row12_col1, #T_0b4f6_row12_col2, #T_0b4f6_row12_col3, #T_0b4f6_row12_col4, #T_0b4f6_row12_col5, #T_0b4f6_row12_col6, #T_0b4f6_row12_col7, #T_0b4f6_row13_col0, #T_0b4f6_row13_col1, #T_0b4f6_row13_col2, #T_0b4f6_row13_col3, #T_0b4f6_row13_col4, #T_0b4f6_row13_col5, #T_0b4f6_row13_col6, #T_0b4f6_row13_col7 {
#   text-align: left;
# }
# #T_0b4f6_row0_col1, #T_0b4f6_row0_col2, #T_0b4f6_row0_col3, #T_0b4f6_row0_col4, #T_0b4f6_row0_col5, #T_0b4f6_row0_col6, #T_0b4f6_row0_col7 {
#   text-align: left;
#   background-color: yellow;
# }
# #T_0b4f6_row0_col8, #T_0b4f6_row1_col8, #T_0b4f6_row2_col8, #T_0b4f6_row3_col8, #T_0b4f6_row4_col8, #T_0b4f6_row5_col8, #T_0b4f6_row6_col8, #T_0b4f6_row7_col8, #T_0b4f6_row8_col8, #T_0b4f6_row9_col8, #T_0b4f6_row10_col8, #T_0b4f6_row11_col8, #T_0b4f6_row13_col8 {
#   text-align: left;
#   background-color: lightgrey;
# }
# #T_0b4f6_row12_col8 {
#   text-align: left;
#   background-color: yellow;
#   background-color: lightgrey;
# }
# </style>
# <table id="T_0b4f6">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_0b4f6_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_0b4f6_level0_col1" class="col_heading level0 col1" >Accuracy</th>
#       <th id="T_0b4f6_level0_col2" class="col_heading level0 col2" >AUC</th>
#       <th id="T_0b4f6_level0_col3" class="col_heading level0 col3" >Recall</th>
#       <th id="T_0b4f6_level0_col4" class="col_heading level0 col4" >Prec.</th>
#       <th id="T_0b4f6_level0_col5" class="col_heading level0 col5" >F1</th>
#       <th id="T_0b4f6_level0_col6" class="col_heading level0 col6" >Kappa</th>
#       <th id="T_0b4f6_level0_col7" class="col_heading level0 col7" >MCC</th>
#       <th id="T_0b4f6_level0_col8" class="col_heading level0 col8" >TT (Sec)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_0b4f6_level0_row0" class="row_heading level0 row0" >lightgbm</th>
#       <td id="T_0b4f6_row0_col0" class="data row0 col0" >Light Gradient Boosting Machine</td>
#       <td id="T_0b4f6_row0_col1" class="data row0 col1" >0.9552</td>
#       <td id="T_0b4f6_row0_col2" class="data row0 col2" >0.9910</td>
#       <td id="T_0b4f6_row0_col3" class="data row0 col3" >0.9552</td>
#       <td id="T_0b4f6_row0_col4" class="data row0 col4" >0.9561</td>
#       <td id="T_0b4f6_row0_col5" class="data row0 col5" >0.9548</td>
#       <td id="T_0b4f6_row0_col6" class="data row0 col6" >0.9388</td>
#       <td id="T_0b4f6_row0_col7" class="data row0 col7" >0.9391</td>
#       <td id="T_0b4f6_row0_col8" class="data row0 col8" >3.5070</td>
#     </tr>
#     <tr>
#       <th id="T_0b4f6_level0_row1" class="row_heading level0 row1" >gbc</th>
#       <td id="T_0b4f6_row1_col0" class="data row1 col0" >Gradient Boosting Classifier</td>
#       <td id="T_0b4f6_row1_col1" class="data row1 col1" >0.9527</td>
#       <td id="T_0b4f6_row1_col2" class="data row1 col2" >0.9901</td>
#       <td id="T_0b4f6_row1_col3" class="data row1 col3" >0.9527</td>
#       <td id="T_0b4f6_row1_col4" class="data row1 col4" >0.9539</td>
#       <td id="T_0b4f6_row1_col5" class="data row1 col5" >0.9524</td>
#       <td id="T_0b4f6_row1_col6" class="data row1 col6" >0.9354</td>
#       <td id="T_0b4f6_row1_col7" class="data row1 col7" >0.9356</td>
#       <td id="T_0b4f6_row1_col8" class="data row1 col8" >4.6960</td>
#     </tr>
#     <tr>
#       <th id="T_0b4f6_level0_row2" class="row_heading level0 row2" >rf</th>
#       <td id="T_0b4f6_row2_col0" class="data row2 col0" >Random Forest Classifier</td>
#       <td id="T_0b4f6_row2_col1" class="data row2 col1" >0.9461</td>
#       <td id="T_0b4f6_row2_col2" class="data row2 col2" >0.9907</td>
#       <td id="T_0b4f6_row2_col3" class="data row2 col3" >0.9461</td>
#       <td id="T_0b4f6_row2_col4" class="data row2 col4" >0.9472</td>
#       <td id="T_0b4f6_row2_col5" class="data row2 col5" >0.9452</td>
#       <td id="T_0b4f6_row2_col6" class="data row2 col6" >0.9263</td>
#       <td id="T_0b4f6_row2_col7" class="data row2 col7" >0.9266</td>
#       <td id="T_0b4f6_row2_col8" class="data row2 col8" >0.2530</td>
#     </tr>
#     <tr>
#       <th id="T_0b4f6_level0_row3" class="row_heading level0 row3" >dt</th>
#       <td id="T_0b4f6_row3_col0" class="data row3 col0" >Decision Tree Classifier</td>
#       <td id="T_0b4f6_row3_col1" class="data row3 col1" >0.9217</td>
#       <td id="T_0b4f6_row3_col2" class="data row3 col2" >0.9496</td>
#       <td id="T_0b4f6_row3_col3" class="data row3 col3" >0.9217</td>
#       <td id="T_0b4f6_row3_col4" class="data row3 col4" >0.9243</td>
#       <td id="T_0b4f6_row3_col5" class="data row3 col5" >0.9217</td>
#       <td id="T_0b4f6_row3_col6" class="data row3 col6" >0.8931</td>
#       <td id="T_0b4f6_row3_col7" class="data row3 col7" >0.8935</td>
#       <td id="T_0b4f6_row3_col8" class="data row3 col8" >0.0350</td>
#     </tr>
#     <tr>
#       <th id="T_0b4f6_level0_row4" class="row_heading level0 row4" >et</th>
#       <td id="T_0b4f6_row4_col0" class="data row4 col0" >Extra Trees Classifier</td>
#       <td id="T_0b4f6_row4_col1" class="data row4 col1" >0.9125</td>
#       <td id="T_0b4f6_row4_col2" class="data row4 col2" >0.9891</td>
#       <td id="T_0b4f6_row4_col3" class="data row4 col3" >0.9125</td>
#       <td id="T_0b4f6_row4_col4" class="data row4 col4" >0.9134</td>
#       <td id="T_0b4f6_row4_col5" class="data row4 col5" >0.9108</td>
#       <td id="T_0b4f6_row4_col6" class="data row4 col6" >0.8799</td>
#       <td id="T_0b4f6_row4_col7" class="data row4 col7" >0.8805</td>
#       <td id="T_0b4f6_row4_col8" class="data row4 col8" >0.2080</td>
#     </tr>
#     <tr>
#       <th id="T_0b4f6_level0_row5" class="row_heading level0 row5" >lda</th>
#       <td id="T_0b4f6_row5_col0" class="data row5 col0" >Linear Discriminant Analysis</td>
#       <td id="T_0b4f6_row5_col1" class="data row5 col1" >0.8718</td>
#       <td id="T_0b4f6_row5_col2" class="data row5 col2" >0.9797</td>
#       <td id="T_0b4f6_row5_col3" class="data row5 col3" >0.8718</td>
#       <td id="T_0b4f6_row5_col4" class="data row5 col4" >0.8721</td>
#       <td id="T_0b4f6_row5_col5" class="data row5 col5" >0.8689</td>
#       <td id="T_0b4f6_row5_col6" class="data row5 col6" >0.8227</td>
#       <td id="T_0b4f6_row5_col7" class="data row5 col7" >0.824
# Transformation Pipeline and Model Successfully Saved
# Transformation Pipeline and Model Successfully Loaded
# <style type="text/css">
# </style>
# <table id="T_33309">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_33309_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_33309_level0_col1" class="col_heading level0 col1" >Accuracy</th>
#       <th id="T_33309_level0_col2" class="col_heading level0 col2" >AUC</th>
#       <th id="T_33309_level0_col3" class="col_heading level0 col3" >Recall</th>
#       <th id="T_33309_level0_col4" class="col_heading level0 col4" >Prec.</th>
#       <th id="T_33309_level0_col5" class="col_heading level0 col5" >F1</th>
#       <th id="T_33309_level0_col6" class="col_heading level0 col6" >Kappa</th>
#       <th id="T_33309_level0_col7" class="col_heading level0 col7" >MCC</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_33309_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_33309_row0_col0" class="data row0 col0" >Light Gradient Boosting Machine</td>
#       <td id="T_33309_row0_col1" class="data row0 col1" >0.9415</td>
#       <td id="T_33309_row0_col2" class="data row0 col2" >0.9884</td>
#       <td id="T_33309_row0_col3" class="data row0 col3" >0.9415</td>
#       <td id="T_33309_row0_col4" class="data row0 col4" >0.9421</td>
#       <td id="T_33309_row0_col5" class="data row0 col5" >0.9414</td>
#       <td id="T_33309_row0_col6" class="data row0 col6" >0.9188</td>
#       <td id="T_33309_row0_col7" class="data row0 col7" >0.9189</td>
#     </tr>
#   </tbody>
# </table>
#         pta_ac     pta_bc    sl   srt     pb     250_ac     500_ac    1000_ac  \
# 0    63.591644  64.071594  95.0  60.0   68.0  40.196838  54.898613  65.444397
# 1    65.624359  50.412266  20.0  45.0    1.0  61.966286  51.229630  46.049465
# 2    18.780752  17.239866  20.0  20.0    7.0  83.625534  60.467449  61.188725
# 3    20.938475  20.690275  30.0  20.0    0.0  16.068274  21.318129  35.746330
# 4    28.033876  25.640808  30.0  30.0    2.0  17.661442  22.450958  25.015066
# ..         ...        ...   ...   ...    ...        ...        ...        ...
# 696  41.159649  27.472963   3.0  40.0   96.0  21.179117  16.434290  10.912289
# 697  15.030734  15.166432  25.0  15.0  100.0  46.046581  41.542656  36.338326
# 698  14.949298  13.343937  30.0  60.0   16.0  21.777626  21.495274  17.106976
# 699  24.182043  23.148726  30.0  29.0   96.0  45.949978  25.913429  30.344566
# 700  23.820906  23.944550  30.0  25.0   96.0  45.153625  41.464161  51.317585
#
#        2000_ac    4000_ac    6000_ac    8000_ac     500_bc    1000_bc  \
# 0    64.824577  75.627983  86.033691  95.068665  54.550320  60.974411
# 1    30.854788  55.671494  66.460533  57.419689  51.462425  46.110741
# 2    62.374153  46.100647  51.843330  71.768677  17.725185  22.247004
# 3    51.314316  70.878555  79.959961  75.858986  22.282335  35.368431
# 4    25.196245  45.040977  31.812569  22.838676  21.910337  21.336765
# ..         ...        ...        ...        ...        ...        ...
# 696  20.798878  25.594488  25.648846  40.940872  15.324203   9.126860
# 697  40.677994  59.986267  49.410858  45.970680  21.830103  11.442636
# 698  21.407763  40.408695  61.193295  55.400532  20.939615  12.351708
# 699  16.912123  35.910408  26.038538  45.192055  24.936766  26.368303
# 700  46.689053  61.013226  65.135162  74.974983  22.465633  30.589321
#
#        2000_bc    4000_bc  severity  prediction_label  prediction_score
# 0    65.577675  71.095963         3                 3            1.0000
# 1    70.737244  54.896503         3                 3            0.9997
# 2    31.614569  22.422012         0                 0            0.9999
# 3    45.790504  71.243340         0                 0            1.0000
# 4    25.935600  45.537395         1                 1            1.0000
# ..         ...        ...       ...               ...               ...
# 696  21.081354  26.238901         1                 1            0.9974
# 697  17.679497  26.203426         0                 0            1.0000
# 698  20.610508  40.582226         0                 0            1.0000
# 699  17.177185  35.311920         0                 0            1.0000
# 700  35.445293  41.176735         0                 0            1.0000
#
# [701 rows x 19 columns]

# %% [markdown]
# manual extrated data

# %%
# hearing loss classificaiton
# Load data
data_path = 'data/train_true.csv'
# prepare data
data = pd.read_csv(data_path, index_col=0).drop('severity', axis=1)
label = ['CHL','SNHL', 'Mixed HL', 'Normal hearing']
data['hearing_loss'] = data['hearing_loss'].map(lambda x: label.index(x))

# setup
experiment_name = 'manual_hearing_loss'
clf = setup(data=data, target='hearing_loss', use_gpu=True, session_id=123, experiment_name=experiment_name)
best_auto = compare_models(n_select=5)

# save model
os.makedirs('models', exist_ok=True)
save_path = os.path.join('models',experiment_name + '_model')
save_model(best_auto[0], save_path)

# evaluate model
eval_dir = os.path.join('evaluate', experiment_name)
os.makedirs(eval_dir,exist_ok=True)    
cf = plot_model(best_auto[0], plot='confusion_matrix', save=True)
roc = plot_model(best_auto[0], save=True)
feature_importance = plot_model(best_auto[0], plot='feature', save=True)

# move evaluate files to evaluate folder
shutil.move('Confusion Matrix.png', os.path.join(eval_dir, 'confusion_matrix.png'))
shutil.move('AUC.png', os.path.join(eval_dir, 'roc.png'))
shutil.move('Feature Importance.png', os.path.join(eval_dir, 'feature_importance.png'))

# test on test set
data_test_path = 'data/test_true.csv'
data_test = pd.read_csv(data_test_path, index_col=0).drop(['severity'], axis=1)
data_test['hearing_loss'] = data_test['hearing_loss'].map(lambda x: label.index(x))

model = load_model(save_path)
predict_model(model, data=data_test)
# Out:
# <style type="text/css">
# #T_e63e2_row8_col1, #T_e63e2_row15_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_e63e2">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_e63e2_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_e63e2_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_e63e2_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_e63e2_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_e63e2_row0_col1" class="data row0 col1" >123</td>
#     </tr>
#     <tr>
#       <th id="T_e63e2_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_e63e2_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_e63e2_row1_col1" class="data row1 col1" >hearing_loss</td>
#     </tr>
#     <tr>
#       <th id="T_e63e2_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_e63e2_row2_col0" class="data row2 col0" >Target type</td>
#       <td id="T_e63e2_row2_col1" class="data row2 col1" >Multiclass</td>
#     </tr>
#     <tr>
#       <th id="T_e63e2_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_e63e2_row3_col0" class="data row3 col0" >Original data shape</td>
#       <td id="T_e63e2_row3_col1" class="data row3 col1" >(2810, 17)</td>
#     </tr>
#     <tr>
#       <th id="T_e63e2_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_e63e2_row4_col0" class="data row4 col0" >Transformed data shape</td>
#       <td id="T_e63e2_row4_col1" class="data row4 col1" >(2810, 17)</td>
#     </tr>
#     <tr>
#       <th id="T_e63e2_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_e63e2_row5_col0" class="data row5 col0" >Transformed train set shape</td>
#       <td id="T_e63e2_row5_col1" class="data row5 col1" >(1966, 17)</td>
#     </tr>
#     <tr>
#       <th id="T_e63e2_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_e63e2_row6_col0" class="data row6 col0" >Transformed test set shape</td>
#       <td id="T_e63e2_row6_col1" class="data row6 col1" >(844, 17)</td>
#     </tr>
#     <tr>
#       <th id="T_e63e2_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_e63e2_row7_col0" class="data row7 col0" >Numeric features</td>
#       <td id="T_e63e2_row7_col1" class="data row7 col1" >16</td>
#     </tr>
#     <tr>
#       <th id="T_e63e2_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_e63e2_row8_col0" class="data row8 col0" >Preprocess</td>
#       <td id="T_e63e2_row8_col1" class="data row8 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_e63e2_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_e63e2_row9_col0" class="data row9 col0" >Imputation type</td>
#       <td id="T_e63e2_row9_col1" class="data row9 col1" >simple</td>
#     </tr>
#     <tr>
#       <th id="T_e63e2_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_e63e2_row10_col0" class="data row10 col0" >Numeric imputation</td>
#       <td id="T_e63e2_row10_col1" class="data row10 col1" >mean</td>
#     </tr>
#     <tr>
#       <th id="T_e63e2_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_e63e2_row11_col0" class="data row11 col0" >Categorical imputation</td>
#       <td id="T_e63e2_row11_col1" class="data row11 col1" >mode</td>
#     </tr>
#     <tr>
#       <th id="T_e63e2_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_e63e2_row12_col0" class="data row12 col0" >Fold Generator</td>
#       <td id="T_e63e2_row12_col1" class="data row12 col1" >StratifiedKFold</td>
#     </tr>
#     <tr>
#       <th id="T_e63e2_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_e63e2_row13_col0" class="data row13 col0" >Fold Number</td>
#       <td id="T_e63e2_row13_col1" class="data row13 col1" >10</td>
#     </tr>
#     <tr>
#       <th id="T_e63e2_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_e63e2_row14_col0" class="data row14 col0" >CPU Jobs</td>
#       <td id="T_e63e2_row14_col1" class="data row14 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_e63e2_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_e63e2_row15_col0" class="data row15 col0" >Use GPU</td>
#       <td id="T_e63e2_row15_col1" class="data row15 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_e63e2_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_e63e2_row16_col0" class="data row16 col0" >Log Experiment</td>
#       <td id="T_e63e2_row16_col1" class="data row16 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_e63e2_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_e63e2_row17_col0" class="data row17 col0" >Experiment Name</td>
#       <td id="T_e63e2_row17_col1" class="data row17 col1" >manual_hearing_loss</td>
#     </tr>
#     <tr>
#       <th id="T_e63e2_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_e63e2_row18_col0" class="data row18 col0" >USI</td>
#       <td id="T_e63e2_row18_col1" class="data row18 col1" >a8cb</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_070f5 th {
#   text-align: left;
# }
# #T_070f5_row0_col0, #T_070f5_row1_col0, #T_070f5_row1_col1, #T_070f5_row1_col2, #T_070f5_row1_col3, #T_070f5_row1_col4, #T_070f5_row1_col5, #T_070f5_row1_col6, #T_070f5_row1_col7, #T_070f5_row2_col0, #T_070f5_row2_col1, #T_070f5_row2_col2, #T_070f5_row2_col3, #T_070f5_row2_col4, #T_070f5_row2_col5, #T_070f5_row2_col6, #T_070f5_row2_col7, #T_070f5_row3_col0, #T_070f5_row3_col1, #T_070f5_row3_col2, #T_070f5_row3_col3, #T_070f5_row3_col4, #T_070f5_row3_col5, #T_070f5_row3_col6, #T_070f5_row3_col7, #T_070f5_row4_col0, #T_070f5_row4_col1, #T_070f5_row4_col2, #T_070f5_row4_col3, #T_070f5_row4_col4, #T_070f5_row4_col5, #T_070f5_row4_col6, #T_070f5_row4_col7, #T_070f5_row5_col0, #T_070f5_row5_col1, #T_070f5_row5_col2, #T_070f5_row5_col3, #T_070f5_row5_col4, #T_070f5_row5_col5, #T_070f5_row5_col6, #T_070f5_row5_col7, #T_070f5_row6_col0, #T_070f5_row6_col1, #T_070f5_row6_col2, #T_070f5_row6_col3, #T_070f5_row6_col4, #T_070f5_row6_col5, #T_070f5_row6_col6, #T_070f5_row6_col7, #T_070f5_row7_col0, #T_070f5_row7_col1, #T_070f5_row7_col2, #T_070f5_row7_col3, #T_070f5_row7_col4, #T_070f5_row7_col5, #T_070f5_row7_col6, #T_070f5_row7_col7, #T_070f5_row8_col0, #T_070f5_row8_col1, #T_070f5_row8_col2, #T_070f5_row8_col3, #T_070f5_row8_col4, #T_070f5_row8_col5, #T_070f5_row8_col6, #T_070f5_row8_col7, #T_070f5_row9_col0, #T_070f5_row9_col1, #T_070f5_row9_col2, #T_070f5_row9_col3, #T_070f5_row9_col4, #T_070f5_row9_col5, #T_070f5_row9_col6, #T_070f5_row9_col7, #T_070f5_row10_col0, #T_070f5_row10_col1, #T_070f5_row10_col2, #T_070f5_row10_col3, #T_070f5_row10_col4, #T_070f5_row10_col5, #T_070f5_row10_col6, #T_070f5_row10_col7, #T_070f5_row11_col0, #T_070f5_row11_col1, #T_070f5_row11_col2, #T_070f5_row11_col3, #T_070f5_row11_col4, #T_070f5_row11_col5, #T_070f5_row11_col6, #T_070f5_row11_col7, #T_070f5_row12_col0, #T_070f5_row12_col1, #T_070f5_row12_col2, #T_070f5_row12_col3, #T_070f5_row12_col4, #T_070f5_row12_col5, #T_070f5_row12_col6, #T_070f5_row12_col7, #T_070f5_row13_col0, #T_070f5_row13_col1, #T_070f5_row13_col2, #T_070f5_row13_col3, #T_070f5_row13_col4, #T_070f5_row13_col5, #T_070f5_row13_col6, #T_070f5_row13_col7 {
#   text-align: left;
# }
# #T_070f5_row0_col1, #T_070f5_row0_col2, #T_070f5_row0_col3, #T_070f5_row0_col4, #T_070f5_row0_col5, #T_070f5_row0_col6, #T_070f5_row0_col7 {
#   text-align: left;
#   background-color: yellow;
# }
# #T_070f5_row0_col8, #T_070f5_row1_col8, #T_070f5_row2_col8, #T_070f5_row3_col8, #T_070f5_row4_col8, #T_070f5_row5_col8, #T_070f5_row6_col8, #T_070f5_row7_col8, #T_070f5_row8_col8, #T_070f5_row9_col8, #T_070f5_row10_col8, #T_070f5_row13_col8 {
#   text-align: left;
#   background-color: lightgrey;
# }
# #T_070f5_row11_col8, #T_070f5_row12_col8 {
#   text-align: left;
#   background-color: yellow;
#   background-color: lightgrey;
# }
# </style>
# <table id="T_070f5">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_070f5_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_070f5_level0_col1" class="col_heading level0 col1" >Accuracy</th>
#       <th id="T_070f5_level0_col2" class="col_heading level0 col2" >AUC</th>
#       <th id="T_070f5_level0_col3" class="col_heading level0 col3" >Recall</th>
#       <th id="T_070f5_level0_col4" class="col_heading level0 col4" >Prec.</th>
#       <th id="T_070f5_level0_col5" class="col_heading level0 col5" >F1</th>
#       <th id="T_070f5_level0_col6" class="col_heading level0 col6" >Kappa</th>
#       <th id="T_070f5_level0_col7" class="col_heading level0 col7" >MCC</th>
#       <th id="T_070f5_level0_col8" class="col_heading level0 col8" >TT (Sec)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_070f5_level0_row0" class="row_heading level0 row0" >rf</th>
#       <td id="T_070f5_row0_col0" class="data row0 col0" >Random Forest Classifier</td>
#       <td id="T_070f5_row0_col1" class="data row0 col1" >0.9456</td>
#       <td id="T_070f5_row0_col2" class="data row0 col2" >0.9881</td>
#       <td id="T_070f5_row0_col3" class="data row0 col3" >0.9456</td>
#       <td id="T_070f5_row0_col4" class="data row0 col4" >0.9481</td>
#       <td id="T_070f5_row0_col5" class="data row0 col5" >0.9447</td>
#       <td id="T_070f5_row0_col6" class="data row0 col6" >0.9012</td>
#       <td id="T_070f5_row0_col7" class="data row0 col7" >0.9028</td>
#       <td id="T_070f5_row0_col8" class="data row0 col8" >0.2370</td>
#     </tr>
#     <tr>
#       <th id="T_070f5_level0_row1" class="row_heading level0 row1" >lightgbm</th>
#       <td id="T_070f5_row1_col0" class="data row1 col0" >Light Gradient Boosting Machine</td>
#       <td id="T_070f5_row1_col1" class="data row1 col1" >0.9440</td>
#       <td id="T_070f5_row1_col2" class="data row1 col2" >0.9874</td>
#       <td id="T_070f5_row1_col3" class="data row1 col3" >0.9440</td>
#       <td id="T_070f5_row1_col4" class="data row1 col4" >0.9466</td>
#       <td id="T_070f5_row1_col5" class="data row1 col5" >0.9438</td>
#       <td id="T_070f5_row1_col6" class="data row1 col6" >0.8996</td>
#       <td id="T_070f5_row1_col7" class="data row1 col7" >0.9006</td>
#       <td id="T_070f5_row1_col8" class="data row1 col8" >2.5030</td>
#     </tr>
#     <tr>
#       <th id="T_070f5_level0_row2" class="row_heading level0 row2" >et</th>
#       <td id="T_070f5_row2_col0" class="data row2 col0" >Extra Trees Classifier</td>
#       <td id="T_070f5_row2_col1" class="data row2 col1" >0.9425</td>
#       <td id="T_070f5_row2_col2" class="data row2 col2" >0.9871</td>
#       <td id="T_070f5_row2_col3" class="data row2 col3" >0.9425</td>
#       <td id="T_070f5_row2_col4" class="data row2 col4" >0.9445</td>
#       <td id="T_070f5_row2_col5" class="data row2 col5" >0.9418</td>
#       <td id="T_070f5_row2_col6" class="data row2 col6" >0.8962</td>
#       <td id="T_070f5_row2_col7" class="data row2 col7" >0.8974</td>
#       <td id="T_070f5_row2_col8" class="data row2 col8" >0.2010</td>
#     </tr>
#     <tr>
#       <th id="T_070f5_level0_row3" class="row_heading level0 row3" >gbc</th>
#       <td id="T_070f5_row3_col0" class="data row3 col0" >Gradient Boosting Classifier</td>
#       <td id="T_070f5_row3_col1" class="data row3 col1" >0.9400</td>
#       <td id="T_070f5_row3_col2" class="data row3 col2" >0.9836</td>
#       <td id="T_070f5_row3_col3" class="data row3 col3" >0.9400</td>
#       <td id="T_070f5_row3_col4" class="data row3 col4" >0.9432</td>
#       <td id="T_070f5_row3_col5" class="data row3 col5" >0.9395</td>
#       <td id="T_070f5_row3_col6" class="data row3 col6" >0.8920</td>
#       <td id="T_070f5_row3_col7" class="data row3 col7" >0.8932</td>
#       <td id="T_070f5_row3_col8" class="data row3 col8" >1.0620</td>
#     </tr>
#     <tr>
#       <th id="T_070f5_level0_row4" class="row_heading level0 row4" >knn</th>
#       <td id="T_070f5_row4_col0" class="data row4 col0" >K Neighbors Classifier</td>
#       <td id="T_070f5_row4_col1" class="data row4 col1" >0.9181</td>
#       <td id="T_070f5_row4_col2" class="data row4 col2" >0.9576</td>
#       <td id="T_070f5_row4_col3" class="data row4 col3" >0.9181</td>
#       <td id="T_070f5_row4_col4" class="data row4 col4" >0.9213</td>
#       <td id="T_070f5_row4_col5" class="data row4 col5" >0.9157</td>
#       <td id="T_070f5_row4_col6" class="data row4 col6" >0.8514</td>
#       <td id="T_070f5_row4_col7" class="data row4 col7" >0.8538</td>
#       <td id="T_070f5_row4_col8" class="data row4 col8" >0.0590</td>
#     </tr>
#     <tr>
#       <th id="T_070f5_level0_row5" class="row_heading level0 row5" >dt</th>
#       <td id="T_070f5_row5_col0" class="data row5 col0" >Decision Tree Classifier</td>
#       <td id="T_070f5_row5_col1" class="data row5 col1" >0.9064</td>
#       <td id="T_070f5_row5_col2" class="data row5 col2" >0.9184</td>
#       <td id="T_070f5_row5_col3" class="data row5 col3" >0.9064</td>
#       <td id="T_070f5_row5_col4" class="data row5 col4" >0.9079</td>
#       <td id="T_070f5_row5_col5" class="data row5 col5" >0.9057</td>
#       <td id="T_070f5_row5_col6" class="data row5 col6" >0.8330</td>
#       <td id="T_070f5_row5_col7" class="data row5 col7" >0.8339</td>
# Transformation Pipeline and Model Successfully Saved
# Transformation Pipeline and Model Successfully Loaded
# <style type="text/css">
# </style>
# <table id="T_f58d7">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_f58d7_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_f58d7_level0_col1" class="col_heading level0 col1" >Accuracy</th>
#       <th id="T_f58d7_level0_col2" class="col_heading level0 col2" >AUC</th>
#       <th id="T_f58d7_level0_col3" class="col_heading level0 col3" >Recall</th>
#       <th id="T_f58d7_level0_col4" class="col_heading level0 col4" >Prec.</th>
#       <th id="T_f58d7_level0_col5" class="col_heading level0 col5" >F1</th>
#       <th id="T_f58d7_level0_col6" class="col_heading level0 col6" >Kappa</th>
#       <th id="T_f58d7_level0_col7" class="col_heading level0 col7" >MCC</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_f58d7_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_f58d7_row0_col0" class="data row0 col0" >Random Forest Classifier</td>
#       <td id="T_f58d7_row0_col1" class="data row0 col1" >0.9458</td>
#       <td id="T_f58d7_row0_col2" class="data row0 col2" >0.9888</td>
#       <td id="T_f58d7_row0_col3" class="data row0 col3" >0.9458</td>
#       <td id="T_f58d7_row0_col4" class="data row0 col4" >0.9465</td>
#       <td id="T_f58d7_row0_col5" class="data row0 col5" >0.9445</td>
#       <td id="T_f58d7_row0_col6" class="data row0 col6" >0.9002</td>
#       <td id="T_f58d7_row0_col7" class="data row0 col7" >0.9012</td>
#     </tr>
#   </tbody>
# </table>
#      pta_ac  pta_bc    sl   srt     pb  250_ac  500_ac  1000_ac  2000_ac  \
# 0      63.0    62.0  25.0  60.0   68.0    50.0    60.0     65.0     65.0
# 1      65.0    50.0  30.0  45.0   72.0    35.0    35.0     45.0     60.0
# 2      17.0    15.0  30.0  20.0   96.0    10.0    10.0     15.0     25.0
# 3      20.0    20.0  30.0  20.0   84.0    20.0    15.0     20.0     25.0
# 4      27.0    25.0  30.0  30.0   92.0    25.0    20.0     30.0     30.0
# ..      ...     ...   ...   ...    ...     ...     ...      ...      ...
# 696    40.0    27.0  30.0  40.0   96.0    30.0    40.0     40.0     40.0
# 697    13.0    13.0  35.0  15.0  100.0    25.0    15.0     15.0     10.0
# 698    13.0    12.0  30.0  10.0   96.0    20.0    15.0     10.0     15.0
# 699    23.0    22.0  30.0  25.0   96.0    25.0    25.0     30.0     20.0
# 700    22.0    22.0  30.0  25.0   96.0    15.0    20.0     25.0     20.0
#
#      4000_ac  6000_ac  8000_ac  500_bc  1000_bc  2000_bc  4000_bc  \
# 0       80.0     95.0     95.0    60.0     65.0     65.0     70.0
# 1      120.0    110.0    100.0    35.0     45.0     70.0     70.0
# 2        5.0     10.0     10.0    10.0     15.0     20.0      5.0
# 3       55.0     50.0     55.0    15.0     20.0     25.0     50.0
# 4       40.0     40.0     45.0    20.0     25.0     30.0     40.0
# ..       ...      ...      ...     ...      ...      ...      ...
# 696     60.0     70.0     85.0    30.0     20.0     30.0     40.0
# 697     10.0     10.0     15.0    15.0     15.0     10.0     10.0
# 698     25.0     30.0     35.0    15.0      5.0     15.0     25.0
# 699     40.0     50.0     45.0    20.0     25.0     20.0     35.0
# 700     30.0     40.0     45.0    20.0     25.0     20.0     30.0
#
#      hearing_loss  prediction_label  prediction_score
# 0               1                 1              1.00
# 1               1                 1              0.81
# 2               3                 3              0.97
# 3               1                 1              1.00
# 4               1                 1              0.98
# ..            ...               ...               ...
# 696             2                 2              0.85
# 697             3                 3              1.00
# 698             1                 1              0.72
# 699             1                 1              0.94
# 700             1                 1              0.97
#
# [701 rows x 19 columns]

# %%
# severity classificaiton
# Load data
data_path = 'data/train_true.csv'
# prepare data
data = pd.read_csv(data_path, index_col=0).drop(['hearing_loss'], axis=1)
label = ['Normal','Mild', 'Moderate', 'Moderately severe',  'Severe', 'Profound']
data['severity'] = data['severity'].map(lambda x: label.index(x))

# setup
experiment_name = 'manual_severity'
clf = setup(data=data, target='severity', use_gpu=True, session_id=123, experiment_name=experiment_name)
best_auto = compare_models(n_select=5)

# save model
os.makedirs('models', exist_ok=True)
save_path = os.path.join('models',experiment_name + '_model')
save_model(best_auto[0], save_path)

# evaluate model
eval_dir = os.path.join('evaluate', experiment_name)
os.makedirs(eval_dir,exist_ok=True)    
cf = plot_model(best_auto[0], plot='confusion_matrix', save=True)
roc = plot_model(best_auto[0], save=True)
feature_importance = plot_model(best_auto[0], plot='feature', save=True)

# move evaluate files to evaluate folder
shutil.move('Confusion Matrix.png', os.path.join(eval_dir, 'confusion_matrix.png'))
shutil.move('AUC.png', os.path.join(eval_dir, 'roc.png'))
shutil.move('Feature Importance.png', os.path.join(eval_dir, 'feature_importance.png'))

# test on test set
data_test_path = 'data/test_true.csv'
data_test = pd.read_csv(data_test_path, index_col=0).drop(['hearing_loss'], axis=1)
data_test['severity'] = data_test['severity'].map(lambda x: label.index(x))

model = load_model(save_path)
predict_model(model, data=data_test)
# Out:
# <style type="text/css">
# #T_b020d_row8_col1, #T_b020d_row15_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_b020d">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_b020d_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_b020d_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_b020d_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_b020d_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_b020d_row0_col1" class="data row0 col1" >123</td>
#     </tr>
#     <tr>
#       <th id="T_b020d_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_b020d_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_b020d_row1_col1" class="data row1 col1" >severity</td>
#     </tr>
#     <tr>
#       <th id="T_b020d_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_b020d_row2_col0" class="data row2 col0" >Target type</td>
#       <td id="T_b020d_row2_col1" class="data row2 col1" >Multiclass</td>
#     </tr>
#     <tr>
#       <th id="T_b020d_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_b020d_row3_col0" class="data row3 col0" >Original data shape</td>
#       <td id="T_b020d_row3_col1" class="data row3 col1" >(2810, 17)</td>
#     </tr>
#     <tr>
#       <th id="T_b020d_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_b020d_row4_col0" class="data row4 col0" >Transformed data shape</td>
#       <td id="T_b020d_row4_col1" class="data row4 col1" >(2810, 17)</td>
#     </tr>
#     <tr>
#       <th id="T_b020d_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_b020d_row5_col0" class="data row5 col0" >Transformed train set shape</td>
#       <td id="T_b020d_row5_col1" class="data row5 col1" >(1966, 17)</td>
#     </tr>
#     <tr>
#       <th id="T_b020d_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_b020d_row6_col0" class="data row6 col0" >Transformed test set shape</td>
#       <td id="T_b020d_row6_col1" class="data row6 col1" >(844, 17)</td>
#     </tr>
#     <tr>
#       <th id="T_b020d_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_b020d_row7_col0" class="data row7 col0" >Numeric features</td>
#       <td id="T_b020d_row7_col1" class="data row7 col1" >16</td>
#     </tr>
#     <tr>
#       <th id="T_b020d_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_b020d_row8_col0" class="data row8 col0" >Preprocess</td>
#       <td id="T_b020d_row8_col1" class="data row8 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_b020d_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_b020d_row9_col0" class="data row9 col0" >Imputation type</td>
#       <td id="T_b020d_row9_col1" class="data row9 col1" >simple</td>
#     </tr>
#     <tr>
#       <th id="T_b020d_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_b020d_row10_col0" class="data row10 col0" >Numeric imputation</td>
#       <td id="T_b020d_row10_col1" class="data row10 col1" >mean</td>
#     </tr>
#     <tr>
#       <th id="T_b020d_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_b020d_row11_col0" class="data row11 col0" >Categorical imputation</td>
#       <td id="T_b020d_row11_col1" class="data row11 col1" >mode</td>
#     </tr>
#     <tr>
#       <th id="T_b020d_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_b020d_row12_col0" class="data row12 col0" >Fold Generator</td>
#       <td id="T_b020d_row12_col1" class="data row12 col1" >StratifiedKFold</td>
#     </tr>
#     <tr>
#       <th id="T_b020d_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_b020d_row13_col0" class="data row13 col0" >Fold Number</td>
#       <td id="T_b020d_row13_col1" class="data row13 col1" >10</td>
#     </tr>
#     <tr>
#       <th id="T_b020d_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_b020d_row14_col0" class="data row14 col0" >CPU Jobs</td>
#       <td id="T_b020d_row14_col1" class="data row14 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_b020d_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_b020d_row15_col0" class="data row15 col0" >Use GPU</td>
#       <td id="T_b020d_row15_col1" class="data row15 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_b020d_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_b020d_row16_col0" class="data row16 col0" >Log Experiment</td>
#       <td id="T_b020d_row16_col1" class="data row16 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_b020d_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_b020d_row17_col0" class="data row17 col0" >Experiment Name</td>
#       <td id="T_b020d_row17_col1" class="data row17 col1" >manual_severity</td>
#     </tr>
#     <tr>
#       <th id="T_b020d_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_b020d_row18_col0" class="data row18 col0" >USI</td>
#       <td id="T_b020d_row18_col1" class="data row18 col1" >37a8</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_968fc th {
#   text-align: left;
# }
# #T_968fc_row0_col0, #T_968fc_row0_col2, #T_968fc_row1_col0, #T_968fc_row1_col1, #T_968fc_row1_col2, #T_968fc_row1_col3, #T_968fc_row1_col4, #T_968fc_row1_col5, #T_968fc_row1_col6, #T_968fc_row1_col7, #T_968fc_row2_col0, #T_968fc_row2_col1, #T_968fc_row2_col3, #T_968fc_row2_col4, #T_968fc_row2_col5, #T_968fc_row2_col6, #T_968fc_row2_col7, #T_968fc_row3_col0, #T_968fc_row3_col1, #T_968fc_row3_col2, #T_968fc_row3_col3, #T_968fc_row3_col4, #T_968fc_row3_col5, #T_968fc_row3_col6, #T_968fc_row3_col7, #T_968fc_row4_col0, #T_968fc_row4_col1, #T_968fc_row4_col2, #T_968fc_row4_col3, #T_968fc_row4_col4, #T_968fc_row4_col5, #T_968fc_row4_col6, #T_968fc_row4_col7, #T_968fc_row5_col0, #T_968fc_row5_col1, #T_968fc_row5_col2, #T_968fc_row5_col3, #T_968fc_row5_col4, #T_968fc_row5_col5, #T_968fc_row5_col6, #T_968fc_row5_col7, #T_968fc_row6_col0, #T_968fc_row6_col1, #T_968fc_row6_col2, #T_968fc_row6_col3, #T_968fc_row6_col4, #T_968fc_row6_col5, #T_968fc_row6_col6, #T_968fc_row6_col7, #T_968fc_row7_col0, #T_968fc_row7_col1, #T_968fc_row7_col2, #T_968fc_row7_col3, #T_968fc_row7_col4, #T_968fc_row7_col5, #T_968fc_row7_col6, #T_968fc_row7_col7, #T_968fc_row8_col0, #T_968fc_row8_col1, #T_968fc_row8_col2, #T_968fc_row8_col3, #T_968fc_row8_col4, #T_968fc_row8_col5, #T_968fc_row8_col6, #T_968fc_row8_col7, #T_968fc_row9_col0, #T_968fc_row9_col1, #T_968fc_row9_col2, #T_968fc_row9_col3, #T_968fc_row9_col4, #T_968fc_row9_col5, #T_968fc_row9_col6, #T_968fc_row9_col7, #T_968fc_row10_col0, #T_968fc_row10_col1, #T_968fc_row10_col2, #T_968fc_row10_col3, #T_968fc_row10_col4, #T_968fc_row10_col5, #T_968fc_row10_col6, #T_968fc_row10_col7, #T_968fc_row11_col0, #T_968fc_row11_col1, #T_968fc_row11_col2, #T_968fc_row11_col3, #T_968fc_row11_col4, #T_968fc_row11_col5, #T_968fc_row11_col6, #T_968fc_row11_col7, #T_968fc_row12_col0, #T_968fc_row12_col1, #T_968fc_row12_col2, #T_968fc_row12_col3, #T_968fc_row12_col4, #T_968fc_row12_col5, #T_968fc_row12_col6, #T_968fc_row12_col7, #T_968fc_row13_col0, #T_968fc_row13_col1, #T_968fc_row13_col2, #T_968fc_row13_col3, #T_968fc_row13_col4, #T_968fc_row13_col5, #T_968fc_row13_col6, #T_968fc_row13_col7 {
#   text-align: left;
# }
# #T_968fc_row0_col1, #T_968fc_row0_col3, #T_968fc_row0_col4, #T_968fc_row0_col5, #T_968fc_row0_col6, #T_968fc_row0_col7, #T_968fc_row2_col2 {
#   text-align: left;
#   background-color: yellow;
# }
# #T_968fc_row0_col8, #T_968fc_row1_col8, #T_968fc_row2_col8, #T_968fc_row3_col8, #T_968fc_row4_col8, #T_968fc_row5_col8, #T_968fc_row6_col8, #T_968fc_row7_col8, #T_968fc_row8_col8, #T_968fc_row9_col8, #T_968fc_row10_col8, #T_968fc_row11_col8, #T_968fc_row12_col8 {
#   text-align: left;
#   background-color: lightgrey;
# }
# #T_968fc_row13_col8 {
#   text-align: left;
#   background-color: yellow;
#   background-color: lightgrey;
# }
# </style>
# <table id="T_968fc">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_968fc_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_968fc_level0_col1" class="col_heading level0 col1" >Accuracy</th>
#       <th id="T_968fc_level0_col2" class="col_heading level0 col2" >AUC</th>
#       <th id="T_968fc_level0_col3" class="col_heading level0 col3" >Recall</th>
#       <th id="T_968fc_level0_col4" class="col_heading level0 col4" >Prec.</th>
#       <th id="T_968fc_level0_col5" class="col_heading level0 col5" >F1</th>
#       <th id="T_968fc_level0_col6" class="col_heading level0 col6" >Kappa</th>
#       <th id="T_968fc_level0_col7" class="col_heading level0 col7" >MCC</th>
#       <th id="T_968fc_level0_col8" class="col_heading level0 col8" >TT (Sec)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_968fc_level0_row0" class="row_heading level0 row0" >rf</th>
#       <td id="T_968fc_row0_col0" class="data row0 col0" >Random Forest Classifier</td>
#       <td id="T_968fc_row0_col1" class="data row0 col1" >0.9674</td>
#       <td id="T_968fc_row0_col2" class="data row0 col2" >0.9886</td>
#       <td id="T_968fc_row0_col3" class="data row0 col3" >0.9674</td>
#       <td id="T_968fc_row0_col4" class="data row0 col4" >0.9685</td>
#       <td id="T_968fc_row0_col5" class="data row0 col5" >0.9673</td>
#       <td id="T_968fc_row0_col6" class="data row0 col6" >0.9556</td>
#       <td id="T_968fc_row0_col7" class="data row0 col7" >0.9558</td>
#       <td id="T_968fc_row0_col8" class="data row0 col8" >0.2380</td>
#     </tr>
#     <tr>
#       <th id="T_968fc_level0_row1" class="row_heading level0 row1" >gbc</th>
#       <td id="T_968fc_row1_col0" class="data row1 col0" >Gradient Boosting Classifier</td>
#       <td id="T_968fc_row1_col1" class="data row1 col1" >0.9654</td>
#       <td id="T_968fc_row1_col2" class="data row1 col2" >0.9879</td>
#       <td id="T_968fc_row1_col3" class="data row1 col3" >0.9654</td>
#       <td id="T_968fc_row1_col4" class="data row1 col4" >0.9664</td>
#       <td id="T_968fc_row1_col5" class="data row1 col5" >0.9653</td>
#       <td id="T_968fc_row1_col6" class="data row1 col6" >0.9528</td>
#       <td id="T_968fc_row1_col7" class="data row1 col7" >0.9530</td>
#       <td id="T_968fc_row1_col8" class="data row1 col8" >1.6020</td>
#     </tr>
#     <tr>
#       <th id="T_968fc_level0_row2" class="row_heading level0 row2" >lightgbm</th>
#       <td id="T_968fc_row2_col0" class="data row2 col0" >Light Gradient Boosting Machine</td>
#       <td id="T_968fc_row2_col1" class="data row2 col1" >0.9654</td>
#       <td id="T_968fc_row2_col2" class="data row2 col2" >0.9888</td>
#       <td id="T_968fc_row2_col3" class="data row2 col3" >0.9654</td>
#       <td id="T_968fc_row2_col4" class="data row2 col4" >0.9664</td>
#       <td id="T_968fc_row2_col5" class="data row2 col5" >0.9653</td>
#       <td id="T_968fc_row2_col6" class="data row2 col6" >0.9527</td>
#       <td id="T_968fc_row2_col7" class="data row2 col7" >0.9529</td>
#       <td id="T_968fc_row2_col8" class="data row2 col8" >3.3310</td>
#     </tr>
#     <tr>
#       <th id="T_968fc_level0_row3" class="row_heading level0 row3" >et</th>
#       <td id="T_968fc_row3_col0" class="data row3 col0" >Extra Trees Classifier</td>
#       <td id="T_968fc_row3_col1" class="data row3 col1" >0.9527</td>
#       <td id="T_968fc_row3_col2" class="data row3 col2" >0.9884</td>
#       <td id="T_968fc_row3_col3" class="data row3 col3" >0.9527</td>
#       <td id="T_968fc_row3_col4" class="data row3 col4" >0.9549</td>
#       <td id="T_968fc_row3_col5" class="data row3 col5" >0.9523</td>
#       <td id="T_968fc_row3_col6" class="data row3 col6" >0.9353</td>
#       <td id="T_968fc_row3_col7" class="data row3 col7" >0.9357</td>
#       <td id="T_968fc_row3_col8" class="data row3 col8" >0.1910</td>
#     </tr>
#     <tr>
#       <th id="T_968fc_level0_row4" class="row_heading level0 row4" >dt</th>
#       <td id="T_968fc_row4_col0" class="data row4 col0" >Decision Tree Classifier</td>
#       <td id="T_968fc_row4_col1" class="data row4 col1" >0.9298</td>
#       <td id="T_968fc_row4_col2" class="data row4 col2" >0.9538</td>
#       <td id="T_968fc_row4_col3" class="data row4 col3" >0.9298</td>
#       <td id="T_968fc_row4_col4" class="data row4 col4" >0.9319</td>
#       <td id="T_968fc_row4_col5" class="data row4 col5" >0.9298</td>
#       <td id="T_968fc_row4_col6" class="data row4 col6" >0.9043</td>
#       <td id="T_968fc_row4_col7" class="data row4 col7" >0.9048</td>
#       <td id="T_968fc_row4_col8" class="data row4 col8" >0.0240</td>
#     </tr>
#     <tr>
#       <th id="T_968fc_level0_row5" class="row_heading level0 row5" >knn</th>
#       <td id="T_968fc_row5_col0" class="data row5 col0" >K Neighbors Classifier</td>
#       <td id="T_968fc_row5_col1" class="data row5 col1" >0.8916</td>
#       <td id="T_968fc_row5_col2" class="data row5 col2" >0.9772</td>
#       <td id="T_968fc_row5_col3" class="data row5 col3" >0.8916</td>
#       <td id="T_968fc_row5_col4" class="data row5 col4" >0.8933</td>
#       <td id="T_968fc_row5_col5" class="data row5 col5" >0.8903</td>
#       <td id="T_968fc_row5_col6" class="data row5 col6" >0.8513</td>
#       <td id="T_968fc_row5_col7" class="data row5 col7" >0.8519</td>
# Transformation Pipeline and Model Successfully Saved
# Transformation Pipeline and Model Successfully Loaded
# <style type="text/css">
# </style>
# <table id="T_e6ea4">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_e6ea4_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_e6ea4_level0_col1" class="col_heading level0 col1" >Accuracy</th>
#       <th id="T_e6ea4_level0_col2" class="col_heading level0 col2" >AUC</th>
#       <th id="T_e6ea4_level0_col3" class="col_heading level0 col3" >Recall</th>
#       <th id="T_e6ea4_level0_col4" class="col_heading level0 col4" >Prec.</th>
#       <th id="T_e6ea4_level0_col5" class="col_heading level0 col5" >F1</th>
#       <th id="T_e6ea4_level0_col6" class="col_heading level0 col6" >Kappa</th>
#       <th id="T_e6ea4_level0_col7" class="col_heading level0 col7" >MCC</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_e6ea4_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_e6ea4_row0_col0" class="data row0 col0" >Random Forest Classifier</td>
#       <td id="T_e6ea4_row0_col1" class="data row0 col1" >0.9643</td>
#       <td id="T_e6ea4_row0_col2" class="data row0 col2" >0.9865</td>
#       <td id="T_e6ea4_row0_col3" class="data row0 col3" >0.9643</td>
#       <td id="T_e6ea4_row0_col4" class="data row0 col4" >0.9645</td>
#       <td id="T_e6ea4_row0_col5" class="data row0 col5" >0.9643</td>
#       <td id="T_e6ea4_row0_col6" class="data row0 col6" >0.9506</td>
#       <td id="T_e6ea4_row0_col7" class="data row0 col7" >0.9506</td>
#     </tr>
#   </tbody>
# </table>
#      pta_ac  pta_bc    sl   srt     pb  250_ac  500_ac  1000_ac  2000_ac  \
# 0      63.0    62.0  25.0  60.0   68.0    50.0    60.0     65.0     65.0
# 1      65.0    50.0  30.0  45.0   72.0    35.0    35.0     45.0     60.0
# 2      17.0    15.0  30.0  20.0   96.0    10.0    10.0     15.0     25.0
# 3      20.0    20.0  30.0  20.0   84.0    20.0    15.0     20.0     25.0
# 4      27.0    25.0  30.0  30.0   92.0    25.0    20.0     30.0     30.0
# ..      ...     ...   ...   ...    ...     ...     ...      ...      ...
# 696    40.0    27.0  30.0  40.0   96.0    30.0    40.0     40.0     40.0
# 697    13.0    13.0  35.0  15.0  100.0    25.0    15.0     15.0     10.0
# 698    13.0    12.0  30.0  10.0   96.0    20.0    15.0     10.0     15.0
# 699    23.0    22.0  30.0  25.0   96.0    25.0    25.0     30.0     20.0
# 700    22.0    22.0  30.0  25.0   96.0    15.0    20.0     25.0     20.0
#
#      4000_ac  6000_ac  8000_ac  500_bc  1000_bc  2000_bc  4000_bc  severity  \
# 0       80.0     95.0     95.0    60.0     65.0     65.0     70.0         3
# 1      120.0    110.0    100.0    35.0     45.0     70.0     70.0         3
# 2        5.0     10.0     10.0    10.0     15.0     20.0      5.0         0
# 3       55.0     50.0     55.0    15.0     20.0     25.0     50.0         0
# 4       40.0     40.0     45.0    20.0     25.0     30.0     40.0         1
# ..       ...      ...      ...     ...      ...      ...      ...       ...
# 696     60.0     70.0     85.0    30.0     20.0     30.0     40.0         1
# 697     10.0     10.0     15.0    15.0     15.0     10.0     10.0         0
# 698     25.0     30.0     35.0    15.0      5.0     15.0     25.0         0
# 699     40.0     50.0     45.0    20.0     25.0     20.0     35.0         0
# 700     30.0     40.0     45.0    20.0     25.0     20.0     30.0         0
#
#      prediction_label  prediction_score
# 0                   3              1.00
# 1                   3              0.57
# 2                   0              0.98
# 3                   0              1.00
# 4                   1              0.82
# ..                ...               ...
# 696                 1              0.93
# 697                 0              1.00
# 698                 0              1.00
# 699                 0              0.91
# 700                 0              1.00
#
# [701 rows x 19 columns]

# %% [markdown]
# # Test model

# %%
# # test model
# test_extract_path = 'data/test_extract.csv'

# y_true_extract = pd.read_csv(test_extract_path, index_col=0).drop(['hearing_loss'], axis=1)
# severity_label = ['Normal','Mild', 'Moderate', 'Moderately severe',  'Severe', 'Profound']
# y_true_extract['severity'] = y_true_extract['severity'].map(lambda x: severity_label.index(x))

# extract_hearing_loss_model = load_model('models/extract_severity_model')
# predict_model(extract_hearing_loss_model, data=y_true_extract)

# %%
# # test model
# test_extract_path = 'data/test_extract.csv'

# y_true_extract = pd.read_csv(test_extract_path, index_col=0).drop(['severity'], axis=1)
# hearing_loss_label = ['CHL','SNHL', 'Mixed HL', 'Normal hearing']
# y_true_extract['hearing_loss'] = y_true_extract['hearing_loss'].map(lambda x: hearing_loss_label.index(x))

# extract_hearing_loss_model = load_model('models/extract_hearing_loss_model')
# predict_model(extract_hearing_loss_model, data=y_true_extract)
