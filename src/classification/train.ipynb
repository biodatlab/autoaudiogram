# %%
from pycaret.classification import *
import pandas as pd
from sklearn.metrics import confusion_matrix, roc_curve, auc
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import LabelBinarizer
import os
import shutil

# %%
plt.rcParams['font.family'] = 'Arial'

# %% [markdown]
# # Train model

# %% [markdown]
# auto extracted data

# %%
# Load data
data_path = 'data/train_extract.csv'
experiment_name = 'extract'
data = pd.read_csv(data_path, index_col=0)

# setup
clf = setup(data=data, target='label', use_gpu=True, session_id=123, experiment_name=experiment_name)
best_ex = compare_models(n_select=5)

# save model
os.makedirs('models', exist_ok=True)
save_path = os.path.join('models',experiment_name + '_model')
save_model(best_ex[0], save_path)

# evaluate model
eval_dir = os.path.join('evaluate', experiment_name)
os.makedirs(eval_dir,exist_ok=True)    
cf = plot_model(best_ex[0], plot='confusion_matrix', save=True)
roc = plot_model(best_ex[0], save=True)
feature_importance = plot_model(best_ex[0], plot='feature', save=True)

# move evaluate files to evaluate folder
shutil.move('Confusion Matrix.png', os.path.join(eval_dir, 'confusion_matrix.png'))
shutil.move('AUC.png', os.path.join(eval_dir, 'roc.png'))
shutil.move('Feature Importance.png', os.path.join(eval_dir, 'feature_importance.png'))
# Out:
# <style type="text/css">
# #T_86d91_row8_col1, #T_86d91_row15_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_86d91_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Description</th>
#       <th class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_86d91_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_86d91_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_86d91_row0_col1" class="data row0 col1" >123</td>
#     </tr>
#     <tr>
#       <th id="T_86d91_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_86d91_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_86d91_row1_col1" class="data row1 col1" >label</td>
#     </tr>
#     <tr>
#       <th id="T_86d91_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_86d91_row2_col0" class="data row2 col0" >Target type</td>
#       <td id="T_86d91_row2_col1" class="data row2 col1" >Multiclass</td>
#     </tr>
#     <tr>
#       <th id="T_86d91_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_86d91_row3_col0" class="data row3 col0" >Original data shape</td>
#       <td id="T_86d91_row3_col1" class="data row3 col1" >(2810, 17)</td>
#     </tr>
#     <tr>
#       <th id="T_86d91_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_86d91_row4_col0" class="data row4 col0" >Transformed data shape</td>
#       <td id="T_86d91_row4_col1" class="data row4 col1" >(2810, 17)</td>
#     </tr>
#     <tr>
#       <th id="T_86d91_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_86d91_row5_col0" class="data row5 col0" >Transformed train set shape</td>
#       <td id="T_86d91_row5_col1" class="data row5 col1" >(1966, 17)</td>
#     </tr>
#     <tr>
#       <th id="T_86d91_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_86d91_row6_col0" class="data row6 col0" >Transformed test set shape</td>
#       <td id="T_86d91_row6_col1" class="data row6 col1" >(844, 17)</td>
#     </tr>
#     <tr>
#       <th id="T_86d91_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_86d91_row7_col0" class="data row7 col0" >Numeric features</td>
#       <td id="T_86d91_row7_col1" class="data row7 col1" >16</td>
#     </tr>
#     <tr>
#       <th id="T_86d91_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_86d91_row8_col0" class="data row8 col0" >Preprocess</td>
#       <td id="T_86d91_row8_col1" class="data row8 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_86d91_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_86d91_row9_col0" class="data row9 col0" >Imputation type</td>
#       <td id="T_86d91_row9_col1" class="data row9 col1" >simple</td>
#     </tr>
#     <tr>
#       <th id="T_86d91_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_86d91_row10_col0" class="data row10 col0" >Numeric imputation</td>
#       <td id="T_86d91_row10_col1" class="data row10 col1" >mean</td>
#     </tr>
#     <tr>
#       <th id="T_86d91_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_86d91_row11_col0" class="data row11 col0" >Categorical imputation</td>
#       <td id="T_86d91_row11_col1" class="data row11 col1" >mode</td>
#     </tr>
#     <tr>
#       <th id="T_86d91_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_86d91_row12_col0" class="data row12 col0" >Fold Generator</td>
#       <td id="T_86d91_row12_col1" class="data row12 col1" >StratifiedKFold</td>
#     </tr>
#     <tr>
#       <th id="T_86d91_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_86d91_row13_col0" class="data row13 col0" >Fold Number</td>
#       <td id="T_86d91_row13_col1" class="data row13 col1" >10</td>
#     </tr>
#     <tr>
#       <th id="T_86d91_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_86d91_row14_col0" class="data row14 col0" >CPU Jobs</td>
#       <td id="T_86d91_row14_col1" class="data row14 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_86d91_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_86d91_row15_col0" class="data row15 col0" >Use GPU</td>
#       <td id="T_86d91_row15_col1" class="data row15 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_86d91_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_86d91_row16_col0" class="data row16 col0" >Log Experiment</td>
#       <td id="T_86d91_row16_col1" class="data row16 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_86d91_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_86d91_row17_col0" class="data row17 col0" >Experiment Name</td>
#       <td id="T_86d91_row17_col1" class="data row17 col1" >extract</td>
#     </tr>
#     <tr>
#       <th id="T_86d91_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_86d91_row18_col0" class="data row18 col0" >USI</td>
#       <td id="T_86d91_row18_col1" class="data row18 col1" >7b52</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_382f5_ th {
#   text-align: left;
# }
# #T_382f5_row0_col0, #T_382f5_row0_col2, #T_382f5_row1_col0, #T_382f5_row1_col1, #T_382f5_row1_col3, #T_382f5_row1_col4, #T_382f5_row1_col5, #T_382f5_row1_col6, #T_382f5_row1_col7, #T_382f5_row2_col0, #T_382f5_row2_col1, #T_382f5_row2_col2, #T_382f5_row2_col3, #T_382f5_row2_col4, #T_382f5_row2_col5, #T_382f5_row2_col6, #T_382f5_row2_col7, #T_382f5_row3_col0, #T_382f5_row3_col1, #T_382f5_row3_col2, #T_382f5_row3_col3, #T_382f5_row3_col4, #T_382f5_row3_col5, #T_382f5_row3_col6, #T_382f5_row3_col7, #T_382f5_row4_col0, #T_382f5_row4_col1, #T_382f5_row4_col2, #T_382f5_row4_col3, #T_382f5_row4_col4, #T_382f5_row4_col5, #T_382f5_row4_col6, #T_382f5_row4_col7, #T_382f5_row5_col0, #T_382f5_row5_col1, #T_382f5_row5_col2, #T_382f5_row5_col3, #T_382f5_row5_col4, #T_382f5_row5_col5, #T_382f5_row5_col6, #T_382f5_row5_col7, #T_382f5_row6_col0, #T_382f5_row6_col1, #T_382f5_row6_col2, #T_382f5_row6_col3, #T_382f5_row6_col4, #T_382f5_row6_col5, #T_382f5_row6_col6, #T_382f5_row6_col7, #T_382f5_row7_col0, #T_382f5_row7_col1, #T_382f5_row7_col2, #T_382f5_row7_col3, #T_382f5_row7_col4, #T_382f5_row7_col5, #T_382f5_row7_col6, #T_382f5_row7_col7, #T_382f5_row8_col0, #T_382f5_row8_col1, #T_382f5_row8_col2, #T_382f5_row8_col3, #T_382f5_row8_col4, #T_382f5_row8_col5, #T_382f5_row8_col6, #T_382f5_row8_col7, #T_382f5_row9_col0, #T_382f5_row9_col1, #T_382f5_row9_col2, #T_382f5_row9_col3, #T_382f5_row9_col4, #T_382f5_row9_col5, #T_382f5_row9_col6, #T_382f5_row9_col7, #T_382f5_row10_col0, #T_382f5_row10_col1, #T_382f5_row10_col2, #T_382f5_row10_col3, #T_382f5_row10_col4, #T_382f5_row10_col5, #T_382f5_row10_col6, #T_382f5_row10_col7, #T_382f5_row11_col0, #T_382f5_row11_col1, #T_382f5_row11_col2, #T_382f5_row11_col3, #T_382f5_row11_col4, #T_382f5_row11_col5, #T_382f5_row11_col6, #T_382f5_row11_col7, #T_382f5_row12_col0, #T_382f5_row12_col1, #T_382f5_row12_col2, #T_382f5_row12_col3, #T_382f5_row12_col4, #T_382f5_row12_col5, #T_382f5_row12_col6, #T_382f5_row12_col7, #T_382f5_row13_col0, #T_382f5_row13_col1, #T_382f5_row13_col2, #T_382f5_row13_col3, #T_382f5_row13_col4, #T_382f5_row13_col5, #T_382f5_row13_col6, #T_382f5_row13_col7 {
#   text-align: left;
# }
# #T_382f5_row0_col1, #T_382f5_row0_col3, #T_382f5_row0_col4, #T_382f5_row0_col5, #T_382f5_row0_col6, #T_382f5_row0_col7, #T_382f5_row1_col2 {
#   text-align: left;
#   background-color: yellow;
# }
# #T_382f5_row0_col8, #T_382f5_row1_col8, #T_382f5_row2_col8, #T_382f5_row3_col8, #T_382f5_row4_col8, #T_382f5_row5_col8, #T_382f5_row6_col8, #T_382f5_row7_col8, #T_382f5_row8_col8, #T_382f5_row9_col8, #T_382f5_row10_col8, #T_382f5_row11_col8, #T_382f5_row13_col8 {
#   text-align: left;
#   background-color: lightgrey;
# }
# #T_382f5_row12_col8 {
#   text-align: left;
#   background-color: yellow;
#   background-color: lightgrey;
# }
# </style>
# <table id="T_382f5_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Model</th>
#       <th class="col_heading level0 col1" >Accuracy</th>
#       <th class="col_heading level0 col2" >AUC</th>
#       <th class="col_heading level0 col3" >Recall</th>
#       <th class="col_heading level0 col4" >Prec.</th>
#       <th class="col_heading level0 col5" >F1</th>
#       <th class="col_heading level0 col6" >Kappa</th>
#       <th class="col_heading level0 col7" >MCC</th>
#       <th class="col_heading level0 col8" >TT (Sec)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_382f5_level0_row0" class="row_heading level0 row0" >gbc</th>
#       <td id="T_382f5_row0_col0" class="data row0 col0" >Gradient Boosting Classifier</td>
#       <td id="T_382f5_row0_col1" class="data row0 col1" >0.9542</td>
#       <td id="T_382f5_row0_col2" class="data row0 col2" >0.9889</td>
#       <td id="T_382f5_row0_col3" class="data row0 col3" >0.9542</td>
#       <td id="T_382f5_row0_col4" class="data row0 col4" >0.9552</td>
#       <td id="T_382f5_row0_col5" class="data row0 col5" >0.9539</td>
#       <td id="T_382f5_row0_col6" class="data row0 col6" >0.9375</td>
#       <td id="T_382f5_row0_col7" class="data row0 col7" >0.9377</td>
#       <td id="T_382f5_row0_col8" class="data row0 col8" >3.2290</td>
#     </tr>
#     <tr>
#       <th id="T_382f5_level0_row1" class="row_heading level0 row1" >lightgbm</th>
#       <td id="T_382f5_row1_col0" class="data row1 col0" >Light Gradient Boosting Machine</td>
#       <td id="T_382f5_row1_col1" class="data row1 col1" >0.9507</td>
#       <td id="T_382f5_row1_col2" class="data row1 col2" >0.9905</td>
#       <td id="T_382f5_row1_col3" class="data row1 col3" >0.9507</td>
#       <td id="T_382f5_row1_col4" class="data row1 col4" >0.9520</td>
#       <td id="T_382f5_row1_col5" class="data row1 col5" >0.9501</td>
#       <td id="T_382f5_row1_col6" class="data row1 col6" >0.9326</td>
#       <td id="T_382f5_row1_col7" class="data row1 col7" >0.9329</td>
#       <td id="T_382f5_row1_col8" class="data row1 col8" >2.8450</td>
#     </tr>
#     <tr>
#       <th id="T_382f5_level0_row2" class="row_heading level0 row2" >rf</th>
#       <td id="T_382f5_row2_col0" class="data row2 col0" >Random Forest Classifier</td>
#       <td id="T_382f5_row2_col1" class="data row2 col1" >0.9502</td>
#       <td id="T_382f5_row2_col2" class="data row2 col2" >0.9903</td>
#       <td id="T_382f5_row2_col3" class="data row2 col3" >0.9502</td>
#       <td id="T_382f5_row2_col4" class="data row2 col4" >0.9508</td>
#       <td id="T_382f5_row2_col5" class="data row2 col5" >0.9496</td>
#       <td id="T_382f5_row2_col6" class="data row2 col6" >0.9319</td>
#       <td id="T_382f5_row2_col7" class="data row2 col7" >0.9322</td>
#       <td id="T_382f5_row2_col8" class="data row2 col8" >0.2070</td>
#     </tr>
#     <tr>
#       <th id="T_382f5_level0_row3" class="row_heading level0 row3" >dt</th>
#       <td id="T_382f5_row3_col0" class="data row3 col0" >Decision Tree Classifier</td>
#       <td id="T_382f5_row3_col1" class="data row3 col1" >0.9222</td>
#       <td id="T_382f5_row3_col2" class="data row3 col2" >0.9499</td>
#       <td id="T_382f5_row3_col3" class="data row3 col3" >0.9222</td>
#       <td id="T_382f5_row3_col4" class="data row3 col4" >0.9247</td>
#       <td id="T_382f5_row3_col5" class="data row3 col5" >0.9218</td>
#       <td id="T_382f5_row3_col6" class="data row3 col6" >0.8940</td>
#       <td id="T_382f5_row3_col7" class="data row3 col7" >0.8947</td>
#       <td id="T_382f5_row3_col8" class="data row3 col8" >0.0310</td>
#     </tr>
#     <tr>
#       <th id="T_382f5_level0_row4" class="row_heading level0 row4" >et</th>
#       <td id="T_382f5_row4_col0" class="data row4 col0" >Extra Trees Classifier</td>
#       <td id="T_382f5_row4_col1" class="data row4 col1" >0.9079</td>
#       <td id="T_382f5_row4_col2" class="data row4 col2" >0.9893</td>
#       <td id="T_382f5_row4_col3" class="data row4 col3" >0.9079</td>
#       <td id="T_382f5_row4_col4" class="data row4 col4" >0.9102</td>
#       <td id="T_382f5_row4_col5" class="data row4 col5" >0.9067</td>
#       <td id="T_382f5_row4_col6" class="data row4 col6" >0.8738</td>
#       <td id="T_382f5_row4_col7" class="data row4 col7" >0.8744</td>
#       <td id="T_382f5_row4_col8" class="data row4 col8" >0.1750</td>
#     </tr>
#     <tr>
#       <th id="T_382f5_level0_row5" class="row_heading level0 row5" >lda</th>
#       <td id="T_382f5_row5_col0" class="data row5 col0" >Linear Discriminant Analysis</td>
#       <td id="T_382f5_row5_col1" class="data row5 col1" >0.8662</td>
#       <td id="T_382f5_row5_col2" class="data row5 col2" >0.9799</td>
#       <td id="T_382f5_row5_col3" class="data row5 col3" >0.8662</td>
#       <td id="T_382f5_row5_col4" class="data row5 col4" >0.8669</td>
#       <td id="T_382f5_row5_col5" class="data row5 col5" >0.8632</td>
#       <td id="T_382f5_row5_col6" class="data row5 col6" >0.8153</td>
#       <td id="T_382f5_row5_col7" class="data row5 col7" >0.8168</td>
#       <td id="T_382f5_row5_col8" class="data row5 col8" >0.0180</td>
#     </tr>
#     <tr>
#       <th id="T_382f5_level0_row6" class="row_heading level0 row6" >ada</th>
#       <td id="T_382f5_row6_col0" class="data row6 c
# Transformation Pipeline and Model Successfully Saved
# 'evaluate\\extract\\feature_importance.png'

# %% [markdown]
# manual extrated data

# %%
# Load data
data_path = 'data/train_true.csv'
experiment_name = 'true'
data = pd.read_csv(data_path, index_col=0)

# setup
clf = setup(data=data, target='label', use_gpu=True, session_id=123, experiment_name=experiment_name)
best_true = compare_models(n_select=5)

# save model
os.makedirs('models', exist_ok=True)
save_path = os.path.join('models',experiment_name + '_model')
save_model(best_true[0], save_path)

# evaluate model
eval_dir = os.path.join('evaluate', experiment_name)
os.makedirs(eval_dir,exist_ok=True)    
cf = plot_model(best_true[0], plot='confusion_matrix', save=True)
roc = plot_model(best_true[0], save=True)
feature_importance = plot_model(best_true[0], plot='feature', save=True)

# move evaluate files to evaluate folder
shutil.move('Confusion Matrix.png', os.path.join(eval_dir, 'confusion_matrix.png'))
shutil.move('AUC.png', os.path.join(eval_dir, 'roc.png'))
shutil.move('Feature Importance.png', os.path.join(eval_dir, 'feature_importance.png'))
# Out:
# <style type="text/css">
# #T_bbcab_row8_col1, #T_bbcab_row15_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_bbcab_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Description</th>
#       <th class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_bbcab_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_bbcab_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_bbcab_row0_col1" class="data row0 col1" >123</td>
#     </tr>
#     <tr>
#       <th id="T_bbcab_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_bbcab_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_bbcab_row1_col1" class="data row1 col1" >label</td>
#     </tr>
#     <tr>
#       <th id="T_bbcab_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_bbcab_row2_col0" class="data row2 col0" >Target type</td>
#       <td id="T_bbcab_row2_col1" class="data row2 col1" >Multiclass</td>
#     </tr>
#     <tr>
#       <th id="T_bbcab_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_bbcab_row3_col0" class="data row3 col0" >Original data shape</td>
#       <td id="T_bbcab_row3_col1" class="data row3 col1" >(2810, 17)</td>
#     </tr>
#     <tr>
#       <th id="T_bbcab_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_bbcab_row4_col0" class="data row4 col0" >Transformed data shape</td>
#       <td id="T_bbcab_row4_col1" class="data row4 col1" >(2810, 17)</td>
#     </tr>
#     <tr>
#       <th id="T_bbcab_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_bbcab_row5_col0" class="data row5 col0" >Transformed train set shape</td>
#       <td id="T_bbcab_row5_col1" class="data row5 col1" >(1966, 17)</td>
#     </tr>
#     <tr>
#       <th id="T_bbcab_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_bbcab_row6_col0" class="data row6 col0" >Transformed test set shape</td>
#       <td id="T_bbcab_row6_col1" class="data row6 col1" >(844, 17)</td>
#     </tr>
#     <tr>
#       <th id="T_bbcab_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_bbcab_row7_col0" class="data row7 col0" >Numeric features</td>
#       <td id="T_bbcab_row7_col1" class="data row7 col1" >16</td>
#     </tr>
#     <tr>
#       <th id="T_bbcab_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_bbcab_row8_col0" class="data row8 col0" >Preprocess</td>
#       <td id="T_bbcab_row8_col1" class="data row8 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_bbcab_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_bbcab_row9_col0" class="data row9 col0" >Imputation type</td>
#       <td id="T_bbcab_row9_col1" class="data row9 col1" >simple</td>
#     </tr>
#     <tr>
#       <th id="T_bbcab_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_bbcab_row10_col0" class="data row10 col0" >Numeric imputation</td>
#       <td id="T_bbcab_row10_col1" class="data row10 col1" >mean</td>
#     </tr>
#     <tr>
#       <th id="T_bbcab_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_bbcab_row11_col0" class="data row11 col0" >Categorical imputation</td>
#       <td id="T_bbcab_row11_col1" class="data row11 col1" >mode</td>
#     </tr>
#     <tr>
#       <th id="T_bbcab_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_bbcab_row12_col0" class="data row12 col0" >Fold Generator</td>
#       <td id="T_bbcab_row12_col1" class="data row12 col1" >StratifiedKFold</td>
#     </tr>
#     <tr>
#       <th id="T_bbcab_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_bbcab_row13_col0" class="data row13 col0" >Fold Number</td>
#       <td id="T_bbcab_row13_col1" class="data row13 col1" >10</td>
#     </tr>
#     <tr>
#       <th id="T_bbcab_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_bbcab_row14_col0" class="data row14 col0" >CPU Jobs</td>
#       <td id="T_bbcab_row14_col1" class="data row14 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_bbcab_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_bbcab_row15_col0" class="data row15 col0" >Use GPU</td>
#       <td id="T_bbcab_row15_col1" class="data row15 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_bbcab_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_bbcab_row16_col0" class="data row16 col0" >Log Experiment</td>
#       <td id="T_bbcab_row16_col1" class="data row16 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_bbcab_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_bbcab_row17_col0" class="data row17 col0" >Experiment Name</td>
#       <td id="T_bbcab_row17_col1" class="data row17 col1" >true</td>
#     </tr>
#     <tr>
#       <th id="T_bbcab_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_bbcab_row18_col0" class="data row18 col0" >USI</td>
#       <td id="T_bbcab_row18_col1" class="data row18 col1" >dee7</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_cfc33_ th {
#   text-align: left;
# }
# #T_cfc33_row0_col0, #T_cfc33_row0_col2, #T_cfc33_row1_col0, #T_cfc33_row1_col1, #T_cfc33_row1_col2, #T_cfc33_row1_col3, #T_cfc33_row1_col4, #T_cfc33_row1_col5, #T_cfc33_row1_col6, #T_cfc33_row1_col7, #T_cfc33_row2_col0, #T_cfc33_row2_col1, #T_cfc33_row2_col3, #T_cfc33_row2_col4, #T_cfc33_row2_col5, #T_cfc33_row2_col6, #T_cfc33_row2_col7, #T_cfc33_row3_col0, #T_cfc33_row3_col1, #T_cfc33_row3_col2, #T_cfc33_row3_col3, #T_cfc33_row3_col4, #T_cfc33_row3_col5, #T_cfc33_row3_col6, #T_cfc33_row3_col7, #T_cfc33_row4_col0, #T_cfc33_row4_col1, #T_cfc33_row4_col2, #T_cfc33_row4_col3, #T_cfc33_row4_col4, #T_cfc33_row4_col5, #T_cfc33_row4_col6, #T_cfc33_row4_col7, #T_cfc33_row5_col0, #T_cfc33_row5_col1, #T_cfc33_row5_col2, #T_cfc33_row5_col3, #T_cfc33_row5_col4, #T_cfc33_row5_col5, #T_cfc33_row5_col6, #T_cfc33_row5_col7, #T_cfc33_row6_col0, #T_cfc33_row6_col1, #T_cfc33_row6_col2, #T_cfc33_row6_col3, #T_cfc33_row6_col4, #T_cfc33_row6_col5, #T_cfc33_row6_col6, #T_cfc33_row6_col7, #T_cfc33_row7_col0, #T_cfc33_row7_col1, #T_cfc33_row7_col2, #T_cfc33_row7_col3, #T_cfc33_row7_col4, #T_cfc33_row7_col5, #T_cfc33_row7_col6, #T_cfc33_row7_col7, #T_cfc33_row8_col0, #T_cfc33_row8_col1, #T_cfc33_row8_col2, #T_cfc33_row8_col3, #T_cfc33_row8_col4, #T_cfc33_row8_col5, #T_cfc33_row8_col6, #T_cfc33_row8_col7, #T_cfc33_row9_col0, #T_cfc33_row9_col1, #T_cfc33_row9_col2, #T_cfc33_row9_col3, #T_cfc33_row9_col4, #T_cfc33_row9_col5, #T_cfc33_row9_col6, #T_cfc33_row9_col7, #T_cfc33_row10_col0, #T_cfc33_row10_col1, #T_cfc33_row10_col2, #T_cfc33_row10_col3, #T_cfc33_row10_col4, #T_cfc33_row10_col5, #T_cfc33_row10_col6, #T_cfc33_row10_col7, #T_cfc33_row11_col0, #T_cfc33_row11_col1, #T_cfc33_row11_col2, #T_cfc33_row11_col3, #T_cfc33_row11_col4, #T_cfc33_row11_col5, #T_cfc33_row11_col6, #T_cfc33_row11_col7, #T_cfc33_row12_col0, #T_cfc33_row12_col1, #T_cfc33_row12_col2, #T_cfc33_row12_col3, #T_cfc33_row12_col4, #T_cfc33_row12_col5, #T_cfc33_row12_col6, #T_cfc33_row12_col7, #T_cfc33_row13_col0, #T_cfc33_row13_col1, #T_cfc33_row13_col2, #T_cfc33_row13_col3, #T_cfc33_row13_col4, #T_cfc33_row13_col5, #T_cfc33_row13_col6, #T_cfc33_row13_col7 {
#   text-align: left;
# }
# #T_cfc33_row0_col1, #T_cfc33_row0_col3, #T_cfc33_row0_col4, #T_cfc33_row0_col5, #T_cfc33_row0_col6, #T_cfc33_row0_col7, #T_cfc33_row2_col2 {
#   text-align: left;
#   background-color: yellow;
# }
# #T_cfc33_row0_col8, #T_cfc33_row1_col8, #T_cfc33_row2_col8, #T_cfc33_row3_col8, #T_cfc33_row4_col8, #T_cfc33_row5_col8, #T_cfc33_row6_col8, #T_cfc33_row7_col8, #T_cfc33_row8_col8, #T_cfc33_row9_col8, #T_cfc33_row10_col8, #T_cfc33_row12_col8 {
#   text-align: left;
#   background-color: lightgrey;
# }
# #T_cfc33_row11_col8, #T_cfc33_row13_col8 {
#   text-align: left;
#   background-color: yellow;
#   background-color: lightgrey;
# }
# </style>
# <table id="T_cfc33_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Model</th>
#       <th class="col_heading level0 col1" >Accuracy</th>
#       <th class="col_heading level0 col2" >AUC</th>
#       <th class="col_heading level0 col3" >Recall</th>
#       <th class="col_heading level0 col4" >Prec.</th>
#       <th class="col_heading level0 col5" >F1</th>
#       <th class="col_heading level0 col6" >Kappa</th>
#       <th class="col_heading level0 col7" >MCC</th>
#       <th class="col_heading level0 col8" >TT (Sec)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_cfc33_level0_row0" class="row_heading level0 row0" >rf</th>
#       <td id="T_cfc33_row0_col0" class="data row0 col0" >Random Forest Classifier</td>
#       <td id="T_cfc33_row0_col1" class="data row0 col1" >0.9649</td>
#       <td id="T_cfc33_row0_col2" class="data row0 col2" >0.9871</td>
#       <td id="T_cfc33_row0_col3" class="data row0 col3" >0.9649</td>
#       <td id="T_cfc33_row0_col4" class="data row0 col4" >0.9662</td>
#       <td id="T_cfc33_row0_col5" class="data row0 col5" >0.9649</td>
#       <td id="T_cfc33_row0_col6" class="data row0 col6" >0.9521</td>
#       <td id="T_cfc33_row0_col7" class="data row0 col7" >0.9523</td>
#       <td id="T_cfc33_row0_col8" class="data row0 col8" >0.2010</td>
#     </tr>
#     <tr>
#       <th id="T_cfc33_level0_row1" class="row_heading level0 row1" >gbc</th>
#       <td id="T_cfc33_row1_col0" class="data row1 col0" >Gradient Boosting Classifier</td>
#       <td id="T_cfc33_row1_col1" class="data row1 col1" >0.9634</td>
#       <td id="T_cfc33_row1_col2" class="data row1 col2" >0.9873</td>
#       <td id="T_cfc33_row1_col3" class="data row1 col3" >0.9634</td>
#       <td id="T_cfc33_row1_col4" class="data row1 col4" >0.9648</td>
#       <td id="T_cfc33_row1_col5" class="data row1 col5" >0.9634</td>
#       <td id="T_cfc33_row1_col6" class="data row1 col6" >0.9500</td>
#       <td id="T_cfc33_row1_col7" class="data row1 col7" >0.9503</td>
#       <td id="T_cfc33_row1_col8" class="data row1 col8" >1.4280</td>
#     </tr>
#     <tr>
#       <th id="T_cfc33_level0_row2" class="row_heading level0 row2" >lightgbm</th>
#       <td id="T_cfc33_row2_col0" class="data row2 col0" >Light Gradient Boosting Machine</td>
#       <td id="T_cfc33_row2_col1" class="data row2 col1" >0.9624</td>
#       <td id="T_cfc33_row2_col2" class="data row2 col2" >0.9879</td>
#       <td id="T_cfc33_row2_col3" class="data row2 col3" >0.9624</td>
#       <td id="T_cfc33_row2_col4" class="data row2 col4" >0.9640</td>
#       <td id="T_cfc33_row2_col5" class="data row2 col5" >0.9624</td>
#       <td id="T_cfc33_row2_col6" class="data row2 col6" >0.9486</td>
#       <td id="T_cfc33_row2_col7" class="data row2 col7" >0.9489</td>
#       <td id="T_cfc33_row2_col8" class="data row2 col8" >2.8230</td>
#     </tr>
#     <tr>
#       <th id="T_cfc33_level0_row3" class="row_heading level0 row3" >et</th>
#       <td id="T_cfc33_row3_col0" class="data row3 col0" >Extra Trees Classifier</td>
#       <td id="T_cfc33_row3_col1" class="data row3 col1" >0.9496</td>
#       <td id="T_cfc33_row3_col2" class="data row3 col2" >0.9873</td>
#       <td id="T_cfc33_row3_col3" class="data row3 col3" >0.9496</td>
#       <td id="T_cfc33_row3_col4" class="data row3 col4" >0.9516</td>
#       <td id="T_cfc33_row3_col5" class="data row3 col5" >0.9493</td>
#       <td id="T_cfc33_row3_col6" class="data row3 col6" >0.9311</td>
#       <td id="T_cfc33_row3_col7" class="data row3 col7" >0.9315</td>
#       <td id="T_cfc33_row3_col8" class="data row3 col8" >0.1730</td>
#     </tr>
#     <tr>
#       <th id="T_cfc33_level0_row4" class="row_heading level0 row4" >dt</th>
#       <td id="T_cfc33_row4_col0" class="data row4 col0" >Decision Tree Classifier</td>
#       <td id="T_cfc33_row4_col1" class="data row4 col1" >0.9257</td>
#       <td id="T_cfc33_row4_col2" class="data row4 col2" >0.9522</td>
#       <td id="T_cfc33_row4_col3" class="data row4 col3" >0.9257</td>
#       <td id="T_cfc33_row4_col4" class="data row4 col4" >0.9279</td>
#       <td id="T_cfc33_row4_col5" class="data row4 col5" >0.9257</td>
#       <td id="T_cfc33_row4_col6" class="data row4 col6" >0.8988</td>
#       <td id="T_cfc33_row4_col7" class="data row4 col7" >0.8992</td>
#       <td id="T_cfc33_row4_col8" class="data row4 col8" >0.0200</td>
#     </tr>
#     <tr>
#       <th id="T_cfc33_level0_row5" class="row_heading level0 row5" >lda</th>
#       <td id="T_cfc33_row5_col0" class="data row5 col0" >Linear Discriminant Analysis</td>
#       <td id="T_cfc33_row5_col1" class="data row5 col1" >0.8876</td>
#       <td id="T_cfc33_row5_col2" class="data row5 col2" >0.9802</td>
#       <td id="T_cfc33_row5_col3" class="data row5 col3" >0.8876</td>
#       <td id="T_cfc33_row5_col4" class="data row5 col4" >0.8890</td>
#       <td id="T_cfc33_row5_col5" class="data row5 col5" >0.8855</td>
#       <td id="T_cfc33_row5_col6" class="data row5 col6" >0.8453</td>
#       <td id="T_cfc33_row5_col7" class="data row5 col7" >0.8464</td>
#       <td id="T_cfc33_row5_col8" class="data row5 col8" >0.0190</td>
#     </tr>
#     <tr>
#       <th id="T_cfc33_level0_row6" class="row_heading level0 row6" >knn</th>
#       <td id="T_cfc33_row6_col0" class="data row6 c
# Transformation Pipeline and Model Successfully Saved
# 'evaluate\\true\\feature_importance.png'

# %% [markdown]
# # Test model

# %%
# test model
test_path = 'data/test_extract.csv'
test_data = pd.read_csv(test_path, index_col=0)

y_true = test_data['label']
x = test_data.drop('label', axis=1)
gbc_auto = load_model('models/extract_model')
df_auto = predict_model(gbc_auto,  data=test_data)
# label_auto = df_auto['label']
# y_pred_auto = df_auto['prediction_label']
label_auto = df_auto['label'].replace({4:5, 5:4})
y_pred_auto = df_auto['prediction_label'].replace({4:5, 5:4})

test_path = 'data/test_true.csv'
test_data = pd.read_csv(test_path, index_col=0)

y_true = test_data['label']
x = test_data.drop('label', axis=1)
rf_mn = load_model('models/true_model')
df_mn = predict_model(rf_mn,  data=test_data)
label_mn = df_mn['label'].replace({4:5, 5:4})
y_pred_mn = df_mn['prediction_label'].replace({4:5, 5:4})
# Out:
# Transformation Pipeline and Model Successfully Loaded
# <style type="text/css">
# </style>
# <table id="T_6452c_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Model</th>
#       <th class="col_heading level0 col1" >Accuracy</th>
#       <th class="col_heading level0 col2" >AUC</th>
#       <th class="col_heading level0 col3" >Recall</th>
#       <th class="col_heading level0 col4" >Prec.</th>
#       <th class="col_heading level0 col5" >F1</th>
#       <th class="col_heading level0 col6" >Kappa</th>
#       <th class="col_heading level0 col7" >MCC</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_6452c_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_6452c_row0_col0" class="data row0 col0" >Gradient Boosting Classifier</td>
#       <td id="T_6452c_row0_col1" class="data row0 col1" >0.9472</td>
#       <td id="T_6452c_row0_col2" class="data row0 col2" >0.9873</td>
#       <td id="T_6452c_row0_col3" class="data row0 col3" >0.9472</td>
#       <td id="T_6452c_row0_col4" class="data row0 col4" >0.9473</td>
#       <td id="T_6452c_row0_col5" class="data row0 col5" >0.9471</td>
#       <td id="T_6452c_row0_col6" class="data row0 col6" >0.9268</td>
#       <td id="T_6452c_row0_col7" class="data row0 col7" >0.9268</td>
#     </tr>
#   </tbody>
# </table>
# Transformation Pipeline and Model Successfully Loaded
# <style type="text/css">
# </style>
# <table id="T_e18dc_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Model</th>
#       <th class="col_heading level0 col1" >Accuracy</th>
#       <th class="col_heading level0 col2" >AUC</th>
#       <th class="col_heading level0 col3" >Recall</th>
#       <th class="col_heading level0 col4" >Prec.</th>
#       <th class="col_heading level0 col5" >F1</th>
#       <th class="col_heading level0 col6" >Kappa</th>
#       <th class="col_heading level0 col7" >MCC</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_e18dc_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_e18dc_row0_col0" class="data row0 col0" >Random Forest Classifier</td>
#       <td id="T_e18dc_row0_col1" class="data row0 col1" >0.9643</td>
#       <td id="T_e18dc_row0_col2" class="data row0 col2" >0.9839</td>
#       <td id="T_e18dc_row0_col3" class="data row0 col3" >0.9643</td>
#       <td id="T_e18dc_row0_col4" class="data row0 col4" >0.9645</td>
#       <td id="T_e18dc_row0_col5" class="data row0 col5" >0.9643</td>
#       <td id="T_e18dc_row0_col6" class="data row0 col6" >0.9505</td>
#       <td id="T_e18dc_row0_col7" class="data row0 col7" >0.9506</td>
#     </tr>
#   </tbody>
# </table>
